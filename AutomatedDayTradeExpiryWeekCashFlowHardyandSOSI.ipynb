# %% [markdown]
# Cash Flow for Hardy + strict SOSI

# %% [markdown]
# 1. Read the best PNL values
# Read the best stop loss and target profit values for NIFTY, BANKNIFTY, and FINNIFTY from a file.
# 2. Filter buy signals
# From the 15-minute chart data, filter out buy signals that are original buy signals and not short signals.
# 3. Calculate charges
# Define a function to calculate the charges for a trade including brokerage, STT/CTT, transaction charges, GST, SEBI charges, and stamp charges.
# 4. Simulate all trades
# For each buy signal, determine the entry price and calculate the profit price and stop price.
# Determine the exit time and price based on subsequent data for the same day.
# Calculate the profit or loss for the trade and append it to the results.
# 5. Simulate live trading account
# Initialize the account with the initial balance.
# Iterate through each second from the earliest entry time to the latest exit time.
# For each second, handle exiting trades first by adding their profit or loss back to the account balance.
# Then, handle entering trades by checking if the account balance is sufficient to cover the trade cost. If not, mark the trade as missed.
# Keep track of the daily balance, executed trades, and missed trades.
# 6. Process each directory
# For each directory (NIFTY, BANKNIFTY, FINNIFTY), load the 15-minute chart data, filter buy signals, and simulate all trades using the best PNL values.
# 7. Combine all trades
# Combine all trades from different indexes into a single DataFrame and sort by entry time.
# 8. Simulate live trading account
# Use the combined trades to simulate the live trading account and get the daily balance, missed trades, and executed trades.
# 9. Save results and generate visualizations
# Save the combined trades, daily balance, missed trades, and executed trades to CSV files.
# Generate visualizations for the daily balance, worst trade, best trade, max drawdown, highest balance, count of missed trades, histogram of trade profits, pie chart of trade outcomes, and summary statistics.
# This approach ensures that the simulation takes into account the initial capital and handles trades in a realistic manner, updating the account balance as trades are

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
import numpy as np

# Function to read best PNL combinations from a file
def read_best_pnl(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        best_pnl_values = {
            'NIFTY': {'stop_loss': float(lines[8].strip()), 'target': float(lines[9].strip())},
            'BANKNIFTY': {'stop_loss': float(lines[10].strip()), 'target': float(lines[11].strip())},
            'FINNIFTY': {'stop_loss': float(lines[12].strip()), 'target': float(lines[13].strip())}
        }
    return best_pnl_values

# Function to read best PNL combinations from a file
def read_best_pnl_Hardy(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        best_pnl_values = {
            'NIFTY': {'stop_loss': float(lines[0].strip()), 'target': float(lines[1].strip())},
            'BANKNIFTY': {'stop_loss': float(lines[2].strip()), 'target': float(lines[3].strip())},
            'FINNIFTY': {'stop_loss': float(lines[4].strip()), 'target': float(lines[5].strip())}
        }
    return best_pnl_values


# Function to calculate indicators and buy signals
def calculate_indicators(data):
   
    # Calculate VWPCI
    if 'volume' in data.columns:
        volume = data['volume']
    elif 'Volume' in data.columns:
        volume = data['Volume']
    data['priceChangeRatio'] = (data['close'] - data['open']) / (data['high'] - data['low'])
    data['VWPCI'] = data['priceChangeRatio'] * volume


    # Convert Unix timestamp (UTC) to datetime
    data['time_utc'] = pd.to_datetime(data['time'], unit='s', utc=True)

    # Convert UTC to IST
    data['time_ist'] = data['time_utc'] + timedelta(hours=5, minutes=30)

    # Calculate ROC
    roc_periods = 14
    data['ROC'] = data['close'].pct_change(periods=roc_periods)

    # Calculate MVI
    data['MVI'] = volume * ((data['close'] - data['open']) / data['close'])

    # Calculate VOLD
    data['up_volume'] = np.where(data['close'] > data['close'].shift(1), volume, 0)
    data['down_volume'] = np.where(data['close'] <= data['close'].shift(1), volume, 0)
    data['total_up_volume'] = data['up_volume'].cumsum()
    data['total_down_volume'] = data['down_volume'].cumsum()
    data['VOLD_ratio'] = data['total_up_volume'] / data['total_down_volume']

    # Normalize VOLD
    data['normalized_vold'] = (data['VOLD_ratio'] - data['VOLD_ratio'].rolling(window=100).min()) / \
                              (data['VOLD_ratio'].rolling(window=100).max() - data['VOLD_ratio'].rolling(window=100).min())

    # Theta Calculation
    days_to_expiration = 30  # assuming a constant value
    d1 = (np.log(data['close'] / data['close']) + (0.05 + (0.2 * 0.2) / 2) * days_to_expiration / 365) / (0.2 * np.sqrt(days_to_expiration / 365))
    d2 = d1 - 0.2 * np.sqrt(days_to_expiration / 365)
    theta_call = -(data['close'] * 0.2 * np.exp(-0.05 * days_to_expiration / 365) * (np.exp(-(d1 ** 2) / 2) / np.sqrt(2 * np.pi))) / \
                 (2 * np.sqrt(days_to_expiration / 365)) - 0.05 * 100 * np.exp(-0.05 * days_to_expiration / 365) * \
                 (np.exp(-(d2 ** 2) / 2) / np.sqrt(2 * np.pi))
    data['theta'] = theta_call

    # Normalize Theta
    data['normalized_theta'] = (data['theta'] - data['theta'].rolling(window=100).min()) / \
                               (data['theta'].rolling(window=100).max() - data['theta'].rolling(window=100).min())

    # Composite SOSI Calculation
    data['sosi_base'] = 0.1 * data['VWPCI'] + 0.2 * data['ROC'] + 0.3 * data['MVI']
    data['sosi'] = data['sosi_base'] + 0.4 * data['normalized_vold'] + 0.1 * data['normalized_theta']

    # Calculate slopes
    data['sosi_slope'] = data['sosi'] - data['sosi'].shift(1)
    data['vold_slope'] = data['normalized_vold'] - data['normalized_vold'].shift(1)

    # Define conditions
    data['condition1'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])
    data['condition2'] = (data['sosi'] > 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] > data['normalized_vold'])
    data['condition3'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['sosi'].shift(1) < data['sosi'].shift(2)) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['normalized_vold'].shift(1) < data['normalized_vold'].shift(2))
    data['condition4'] = (data['sosi_slope'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])

    # Combine conditions into the buy signal
    data['Buy Signal SOSI Final'] = (data['time_ist'].dt.time == pd.Timestamp('09:20:00').time()) & (data['condition1'] | data['condition2'] | data['condition3'] | data['condition4'])

    return data

# Function to filter buy signals from the 15-minute chart data
def filter_signals_Hardy(data):
    buy_signals = data[(data['Original Buy Signal'] == True) & (data['Short Signal'] == False)]
    return buy_signals


# Function to filter buy signals from the 1-minute chart data
def filter_signals(data):
    if 'Buy Signal SOSI Final' not in data.columns:
        print("Warning: 'Buy Signal SOSI Final' column not found in the data.")
        if 'volume' and 'Volume' not in data.columns:
            print("Error: 'volume' column not found in the data.")
            return pd.DataFrame()
        data=calculate_indicators(data)
        if 'Buy Signal SOSI Final' not in data.columns:
            print("Error: 'Buy Signal SOSI Final' column still not found in the data.")
            return pd.DataFrame()
        buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
        return buy_signals
        

    buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
    return buy_signals



# Function to calculate charges
def calculate_charges(entry_price, exit_price, quantity):
    brokerage = 40  # total brokerage for one complete buy and sell
    stt_ctt = 0.00125 * exit_price * quantity
    transaction_charges = 0.000495 * (entry_price + exit_price) * quantity
    gst = 0.18 * (brokerage + transaction_charges)
    sebi_charges = 10 / 10**7 * (entry_price + exit_price) * quantity
    stamp_charges = 0.00003 * entry_price * quantity
    total_charges = brokerage + stt_ctt + transaction_charges + gst + sebi_charges + stamp_charges
    return total_charges

# Function to simulate day trades with error margin
def simulate_day_trades(buy_signals, minute_data, symbol, profit_target=0.02, stop_loss=0.01, min_stop_loss=0.005, error_margin=0.01):
    results = []

    for index, buy_signal in buy_signals.iterrows():
        entry_price = buy_signal['close'] #* (1 + error_margin)  # Adjust entry price with error margin
        entry_time = buy_signal['time'] + 900  # Add 15 minutes to the buy signal time to get the entry time
        profit_price = entry_price * (1 + profit_target)
        stop_price = entry_price * (1 - max(stop_loss, min_stop_loss))  # Ensure stop loss is at least min_stop_loss
        
        trade_result = {
            'symbol': symbol,
            'signal_time': buy_signal['time'],
            'entry_time': entry_time,
            'entry_price': entry_price,
            'Target Profit': profit_target,
            'Stop Loss': stop_loss,
            'Profit Price': profit_price,
            'Stop Price': stop_price,
            'exit_time': None,
            'exit_price': None,
            'charges': None,
            'profit_before_charges': None,
            'profit': None,
            'exit_reason': None,
            'missed': False
        }
        
        # Filter subsequent data for the same day only
        trade_date = pd.to_datetime(entry_time, unit='s').date()
        subsequent_data = minute_data[(minute_data['time'] > entry_time) & 
                                      (pd.to_datetime(minute_data['time'], unit='s').dt.date == trade_date)]
      
        error_margin = 0  # Default error margin for 1-minute data

        if subsequent_data.empty:
            # Use 15-minute chart data if 1-minute data is empty
            subsequent_data = minute_data_15[(minute_data_15['time'] > entry_time) & 
                                             (pd.to_datetime(minute_data_15['time'], unit='s').dt.date == trade_date)]
            error_margin = 960  # Adjust error margin for 15-minute data
            
        for _, row in subsequent_data.iterrows():
            if row['high'] >= profit_price:
                trade_result['exit_time'] = row['time'] + error_margin
                trade_result['exit_price'] = profit_price
                trade_result['exit_reason'] = 'Target Hit'
                break
            if row['low'] <= stop_price:
                trade_result['exit_time'] = row['time'] + error_margin
                trade_result['exit_price'] = stop_price
                trade_result['exit_reason'] = 'Stop Loss Hit'
                break
        else:
            # If no target or stop loss hit, exit at the last price of the day (3:25 PM)
            end_of_day_time = pd.to_datetime(trade_date) + pd.Timedelta(hours=15, minutes=25)
            eod_exit_data = minute_data[(pd.to_datetime(minute_data['time'], unit='s') <= end_of_day_time)]
            
            if eod_exit_data.empty:
                eod_exit_data = minute_data_15[(pd.to_datetime(minute_data_15['time'], unit='s') <= end_of_day_time)]
            
            if not eod_exit_data.empty:
                last_row = eod_exit_data.iloc[-1]
                trade_result['exit_time'] = last_row['time'] + error_margin
                trade_result['exit_price'] = last_row['close']
                trade_result['exit_reason'] = 'End of Day Exit'
        
        if trade_result['exit_price'] is not None:
            quantity = 25 if 'NIFTY' in symbol else 15 if 'BANKNIFTY' in symbol else 40 if 'FINNIFTY' in symbol else 10
            gross_profit = (trade_result['exit_price'] - trade_result['entry_price']) * quantity
            charges = calculate_charges(trade_result['entry_price'], trade_result['exit_price'], quantity)
            net_profit = gross_profit - charges
            trade_result['charges'] = charges
            trade_result['profit_before_charges'] = gross_profit
            trade_result['profit'] = net_profit

        results.append(trade_result)
    
    results_df = pd.DataFrame(results)

    return results_df.dropna(subset=['entry_price'])

# Function to simulate live trading account
def simulate_live_trading(all_trades, initial_balance):
    account_balance = initial_balance
    active_trades = []
    daily_balance = []
    missed_trades = []
    executed_trades = []

    current_time = pd.to_datetime(all_trades['entry_time'].min(), unit='s')
    end_time = pd.to_datetime(all_trades['exit_time'].max(), unit='s')
    print(f"Simulating live trading from {current_time} to {end_time}...")

    trading_end_time = current_time.replace(hour=11, minute=30, second=0, microsecond=0)

    while current_time <= end_time:


        # Skip non-trading hours
        if current_time.time() > trading_end_time.time():
            current_time = current_time + timedelta(days=1)
            current_time = current_time.replace(hour=3, minute=30, second=0, microsecond=0)
            continue

        # Handle exiting trades
        trades_to_remove = []
        for trade in active_trades:
            if trade['exit_time'] == current_time:
                print(f"Exiting trade at {trade['exit_price']} at {current_time}")
                trade_cost = trade['entry_price'] * (25 if 'NIFTY' in trade['symbol'] else 15 if 'BANKNIFTY' in trade['symbol'] else 40 if 'FINNIFTY' in trade['symbol'] else 10)
                account_balance += trade['profit'] + trade_cost
                print(f"Account Balance: {account_balance}")
                executed_trades.append(trade)
                trades_to_remove.append(trade.name)

        # Remove trades that have exited
        active_trades = [trade for trade in active_trades if trade.name not in trades_to_remove]

    

        # Handle entering trades
        current_trades = all_trades[all_trades['entry_time'] == current_time]
        if not current_trades.empty:
            print(f"Entering {len(current_trades)} trades at {current_time}")
        for index, trade in current_trades.iterrows():
            trade_cost = trade['entry_price'] * (25 if 'NIFTY' in trade['symbol'] else 15 if 'BANKNIFTY' in trade['symbol'] else 40 if 'FINNIFTY' in trade['symbol'] else 10)
            if account_balance >= trade_cost:
                account_balance -= trade_cost  # Deduct the trade cost from account balance
                active_trades.append(trade)
                print(f"Account Balance: {account_balance}")
                print(f"Entered trade at {trade['entry_price']} for {trade_cost} at {current_time}")
            else:
                trade['missed'] = True
                print(f"Missed trade at {trade['entry_price']} due to insufficient balance at {current_time}")
                missed_trades.append(trade)

        daily_balance.append({'date': current_time.date(), 'balance': account_balance})
        current_time += timedelta(seconds=1)

    daily_balance_df = pd.DataFrame(daily_balance).groupby('date').last().reset_index()
    missed_trades_df = pd.DataFrame(missed_trades)
    executed_trades_df = pd.DataFrame(executed_trades)
    print("Total trades executed:", len(executed_trades_df))
    print("Total missed trades:", len(missed_trades_df))
    print("Live trading simulation complete.")

    return daily_balance_df, missed_trades_df, executed_trades_df


# Function to check if the date is within the week of expiration
def is_within_expiry_week(expiry_date, timestamp, folder_name, days_before_expiry=5):
    # Assuming the date is the 7th to 12th characters in the string
    if folder_name == 'NIFTY':
        date_part = expiry_date[9:15]
    if folder_name == 'BANKNIFTY':
        date_part = expiry_date[13:19]
    if folder_name == 'FINNIFTY':
        date_part = expiry_date[12:18]
    if folder_name == 'SENSEX':
        date_part = expiry_date[7:13]
    
    expiry_datetime = pd.to_datetime(date_part, format='%y%m%d')
    signal_datetime = pd.to_datetime(timestamp, unit='s')
    return (expiry_datetime - signal_datetime).days <= days_before_expiry


# Read the best PNL values
best_pnl_file_path = 'bestpnlAnalysis.txt'
best_pnl_values = read_best_pnl(best_pnl_file_path)
best_pnl_values_hardy = read_best_pnl_Hardy(best_pnl_file_path)

# Directories containing the data
directories = ['June 2024/NIFTY', 'June 2024/BANKNIFTY', 'June 2024/FINNIFTY']  # Change the directories as needed

# Initial balance for the account
initial_balance = 100000  # Starting with 20000 INR

# Process each directory
all_trades = []

for directory in directories:
    folder_name = os.path.basename(directory)
    for subdir, _, files in os.walk(directory):
        if subdir == directory:
            continue  # Skip the top-level directory itself
        for filename in files:
            if ', 1.csv' in filename:
                minute_15_path = os.path.join(subdir, filename)
                
                if os.path.exists(minute_15_path):
                    print(f"Processing {filename} in {folder_name}...")
                    
                    # Extract expiry date from filename
                    # Extract expiry date from filename
                    expiry_date = filename.split(' ')[0].split(',')[0]
                    
                    # Load the CSV file
                    minute_data_15 = pd.read_csv(minute_15_path)
                    
                    # Filter buy signals
                    buy_signals = filter_signals(minute_data_15)

                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found for {filename}. Skipping...")
                        continue

                    # Filter signals to only include those within the expiry week
                    buy_signals = buy_signals[buy_signals['time'].apply(lambda x: is_within_expiry_week(expiry_date, x, folder_name))]
                    
                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found within expiry week for {filename}. Skipping...")
                        continue
                    
                    # Get best PNL values for the current index
                    stop_loss = best_pnl_values_hardy[folder_name]['stop_loss']
                    profit_target = best_pnl_values_hardy[folder_name]['target']

                    # Simulate all trades
                    trades = simulate_day_trades(buy_signals, minute_data_15, folder_name, profit_target, stop_loss)
                    all_trades.append(trades)

#Check all buy signals for Hardy
for directory in directories:
    folder_name = os.path.basename(directory)
    for subdir, _, files in os.walk(directory):
        if subdir == directory:
            continue  # Skip the top-level directory itself
        for filename in files:
            if ', 15.csv' in filename:
                minute_15_path = os.path.join(subdir, filename)
                
                if os.path.exists(minute_15_path):
                    print(f"Processing {filename} in {folder_name}...")
                    
                    # Extract expiry date from filename
                    # Extract expiry date from filename
                    expiry_date = filename.split(' ')[0].split(',')[0]
                    
                    # Load the CSV file
                    minute_data_15 = pd.read_csv(minute_15_path)
                    
                    # Filter buy signals
                    buy_signals = filter_signals_Hardy(minute_data_15)

                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found for {filename}. Skipping...")
                        continue

                    # Filter signals to only include those within the expiry week
                    buy_signals = buy_signals[buy_signals['time'].apply(lambda x: is_within_expiry_week(expiry_date, x, folder_name))]
                    
                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found within expiry week for {filename}. Skipping...")
                        continue
                    
                    # Get best PNL values for the current index
                    stop_loss = best_pnl_values[folder_name]['stop_loss']
                    profit_target = best_pnl_values[folder_name]['target']

                    # Simulate all trades
                    trades = simulate_day_trades(buy_signals, minute_data_15, folder_name, profit_target, stop_loss)
                    all_trades.append(trades)


# Combine all trades from different indexes
all_trades_df = pd.concat(all_trades, ignore_index=True)
all_trades_df['entry_time'] = pd.to_datetime(all_trades_df['entry_time'], unit='s')
all_trades_df['exit_time'] = pd.to_datetime(all_trades_df['exit_time'], unit='s')
all_trades_df = all_trades_df.sort_values(by='entry_time').reset_index(drop=True)

# Simulate live trading account
daily_balance_df, missed_trades_df, executed_trades_df = simulate_live_trading(all_trades_df, initial_balance)

# Create output directories
combined_output_dir = 'Outputs/DayTrade/Combined'
os.makedirs(combined_output_dir, exist_ok=True)

# Save combined trades and daily balance
all_trades_df.to_csv(f'{combined_output_dir}/all_trades.csv', index=False)
daily_balance_df.to_csv(f'{combined_output_dir}/daily_balance.csv', index=False)
missed_trades_df.to_csv(f'{combined_output_dir}/missed_trades.csv', index=False)
executed_trades_df.to_csv(f'{combined_output_dir}/executed_trades.csv', index=False)

# Plot the combined daily balance for all indexes
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['balance'], marker='o', linestyle='-', color='blue')
plt.xlabel('Date')
plt.ylabel('Account Balance')
plt.title('Daily Account Balance for Combined Trades Across All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/daily_balance.png')
plt.close()

# Calculate and plot the worst trade for all indexes
worst_trade_all = executed_trades_df.loc[executed_trades_df['profit'].idxmin()]
plt.figure(figsize=(12, 8))
plt.barh(['Worst Trade'], [worst_trade_all['profit']], color='red')
plt.xlabel('Profit')
plt.ylabel('Worst Trade')
plt.title('Worst Trade for All Indexes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/worst_trade_all.png')
plt.close()

# Calculate and plot the best trade for all indexes
best_trade_all = executed_trades_df.loc[executed_trades_df['profit'].idxmax()]
plt.figure(figsize=(12, 8))
plt.barh(['Best Trade'], [best_trade_all['profit']], color='green')
plt.xlabel('Profit')
plt.ylabel('Best Trade')
plt.title('Best Trade for All Indexes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/best_trade_all.png')
plt.close()

# Calculate and plot the max drawdown for all indexes
daily_balance_df['drawdown'] = daily_balance_df['balance'].cummax() - daily_balance_df['balance']
max_drawdown_all = daily_balance_df['drawdown'].max()
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['drawdown'], marker='o', linestyle='-', color='orange')
plt.xlabel('Date')
plt.ylabel('Drawdown')
plt.title('Max Drawdown for All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/max_drawdown_all.png')
plt.close()

# Calculate and plot the highest balance on each day for all indexes
daily_balance_df['highest_balance'] = daily_balance_df['balance'].cummax()
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['highest_balance'], marker='o', linestyle='-', color='purple')
plt.xlabel('Date')
plt.ylabel('Highest Balance')
plt.title('Highest Balance for All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/highest_balance_all.png')
plt.close()

# Calculate and plot missed trades due to insufficient capital
missed_trades_profitable = missed_trades_df[missed_trades_df['profit'] > 0]
missed_trades_loss = missed_trades_df[missed_trades_df['profit'] <= 0]
plt.figure(figsize=(12, 8))
plt.bar(['Profitable Missed Trades', 'Loss Making Missed Trades'], [len(missed_trades_profitable), len(missed_trades_loss)], color=['lightgreen', 'lightcoral'])
plt.xlabel('Type of Missed Trades')
plt.ylabel('Count')
plt.title('Count of Missed Trades Due to Insufficient Capital')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/missed_trades_count.png')
plt.close()

# Plot a histogram of trade profits
plt.figure(figsize=(12, 8))
plt.hist(executed_trades_df['profit'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.title('Histogram of Trade Profits')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/trade_profits_histogram.png')
plt.close()

# Pie chart of trade outcomes
outcomes = executed_trades_df['exit_reason'].value_counts()
plt.figure(figsize=(12, 8))
plt.pie(outcomes, labels=outcomes.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue', 'lightgreen'])
plt.title('Trade Outcomes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/trade_outcomes_pie_chart.png')
plt.close()

# Summary statistics
summary_stats = {
    'Total Trades': len(executed_trades_df),
    'Total Missed Trades': len(missed_trades_df),
    'Total Profit': executed_trades_df['profit'].sum(),
    'Max Drawdown': max_drawdown_all,
    'Best Trade': best_trade_all['profit'],
    'Worst Trade': worst_trade_all['profit']
}
summary_stats_df = pd.DataFrame([summary_stats])
summary_stats_df.to_csv(f'{combined_output_dir}/summary_statistics.csv', index=False)

# Visualize summary statistics
plt.figure(figsize=(22, 18))
plt.barh(list(summary_stats.keys()), list(summary_stats.values()), color='skyblue')
plt.xlabel('Value')
plt.ylabel('Statistic')
plt.title('Summary Statistics')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/summary_statistics.png')
plt.close()

print("Final summary statistics:")
print(summary_stats_df)
print("Final Balance:", daily_balance_df['balance'].iloc[-1])
print("Max Drawdown:", max_drawdown_all)
print("Best Trade:", best_trade_all['profit'])
print("Worst Trade:", worst_trade_all['profit'])
print("Total Trades:", len(executed_trades_df))
print("Total Missed Trades:", len(missed_trades_df))
print("Total Profit:", executed_trades_df['profit'].sum())
print("Total Profitable Trades:", len(executed_trades_df[executed_trades_df['profit'] > 0]))


print("Analysis and visualization complete.")
# Out:
# Processing NSE_NIFTY240620C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23300, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23450, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23450, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23750, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23750, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23900, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24050, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C24050, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24250, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240711C24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24250, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24350, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240718P24200, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24200, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24300, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24300, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24400, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24400, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24500, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52100, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_BANKNIFTY240703C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710P52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C51900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52500, 1.csv in BANKNIFTY...
# Processing NSE_FINNIFTY240625C22500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23200, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C24000, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_FINNIFTY240709P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240709P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P24000, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23400, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23700, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C24000, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23400, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23550, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23700, 1.csv in FINNIFTY...
# Processing NSE_NIFTY240620C23400, 15.csv in NIFTY...
# Processing NSE_NIFTY240620C23500, 15.csv in NIFTY...
# Processing NSE_NIFTY240620C23550, 15.csv in NIFTY...
# Processing NSE_NIFTY240620C23600, 15.csv in NIFTY...
# Processing NSE_NIFTY240620P23400, 15.csv in NIFTY...
# Processing NSE_NIFTY240620P23500, 15.csv in NIFTY...
# Processing NSE_NIFTY240620P23550, 15.csv in NIFTY...
# Processing NSE_NIFTY240620P23600, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23300, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23400, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23450, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23500, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23550, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23600, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23700, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23750, 15.csv in NIFTY...
# Processing NSE_NIFTY240627C23800, 15.csv in NIFTY...
# Processing NSE_NIFTY240627P23400, 15.csv in NIFTY...
# Processing NSE_NIFTY240627P23500, 15.csv in NIFTY...
# Processing NSE_NIFTY240627P23600, 15.csv in NIFTY...
# Processing NSE_NIFTY240627P23700, 15.csv in NIFTY...
# Processing NSE_NIFTY240627P23800, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C23700, 15.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240704C23700, 15.csv. Skipping...
# Processing NSE_NIFTY240704C23800, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C23900, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24000, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24050, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24100, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24150, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24200, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24250, 15.csv in NIFTY...
# Processing NSE_NIFTY240704C24300, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P23800, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P23900, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P24000, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P24100, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P24150, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P24200, 15.csv in NIFTY...
# Processing NSE_NIFTY240704P24300, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24200, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24250, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24300, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24350, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24400, 15.csv in NIFTY...
# Processing NSE_NIFTY240711C24500, 15.csv in NIFTY...
# Processing NSE_NIFTY240711P24200, 15.csv in NIFTY...
# Processing NSE_NIFTY240711P24300, 15.csv in NIFTY...
# Processing NSE_NIFTY240711P24400, 15.csv in NIFTY...
# Processing NSE_NIFTY240711P24500, 15.csv in NIFTY...
# Processing NSE_NIFTY240718C24200, 15.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718C24200, 15.csv. Skipping...
# Processing NSE_NIFTY240718C24300, 15.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718C24300, 15.csv. Skipping...
# Processing NSE_NIFTY240718C24400, 15.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718C24400, 15.csv. Skipping...
# Processing NSE_NIFTY240718C24500, 15.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718C24500, 15.csv. Skipping...
# Processing NSE_NIFTY240718P24200, 15.csv in NIFTY...
# Processing NSE_NIFTY240718P24300, 15.csv in NIFTY...
# Processing NSE_NIFTY240718P24400, 15.csv in NIFTY...
# Processing NSE_NIFTY240718P24500, 15.csv in NIFTY...
# Processing NSE_BANKNIFTY240619C50400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240619C50500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240619C50600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240619P50400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240619P50500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240619P50600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51700, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51800, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C51900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C52000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C52100, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626C52600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626P51300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626P51400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626P51500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240626P51600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52700, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52800, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C52900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703C53000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52700, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52800, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P52900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240703P53000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52700, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52800, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53100, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52600, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52700, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52800, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53100, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C51900, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52500, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52000, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52200, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52300, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52400, 15.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52500, 15.csv in BANKNIFTY...
# Processing NSE_FINNIFTY240625C22500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625C22800, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625C22900, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625C23000, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625C23100, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625C23500, 15.csv in FINNIFTY...
# No buy signals found within expiry week for NSE_FINNIFTY240625C23500, 15.csv. Skipping...
# Processing NSE_FINNIFTY240625P22800, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625P22900, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625P23000, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240625P23100, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23100, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240702C23100, 15.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240702C23200, 15.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240702C23300, 15.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23450, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240702C23450, 15.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23550, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23650, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702C23700, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23100, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23300, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23450, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23550, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23650, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23700, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240702P23800, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23700, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23800, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23900, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C24000, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23450, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P23450, 15.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23700, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23800, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23900, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P23900, 15.csv. Skipping...
# Processing NSE_FINNIFTY240709P24000, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P24000, 15.csv. Skipping...
# Processing NSE_FINNIFTY240716C23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23700, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C24000, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23400, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23500, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23550, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23600, 15.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23700, 15.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716P23700, 15.csv. Skipping...
# Simulating live trading from 2024-06-13 05:45:00 to 2024-07-12 10:00:00...
# Entering 1 trades at 2024-06-13 05:45:00
# Account Balance: 95775.0
# Entered trade at 169.0 for 4225.0 at 2024-06-13 05:45:00
# Entering 2 trades at 2024-06-13 06:00:00
# Account Balance: 92850.0
# Entered trade at 117.0 for 2925.0 at 2024-06-13 06:00:00
# Account Balance: 89300.0
# Entered trade at 142.0 for 3550.0 at 2024-06-13 06:00:00
# Exiting trade at 162.23999999999998 at 2024-06-13 07:30:00
# Account Balance: 93298.7580369
# Exiting trade at 112.32 at 2024-06-13 07:30:00
# Account Balance: 96052.6059086
# Exiting trade at 136.32 at 2024-06-13 07:30:00
# Account Balance: 99404.96828280001
# Entering 3 trades at 2024-06-13 09:15:00
# Account Balance: 96371.21828280001
# Entered trade at 121.35 for 3033.75 at 2024-06-13 09:15:00
# Account Balance: 93876.21828280001
# Entered trade at 99.8 for 2495.0 at 2024-06-13 09:15:00
# Account Balance: 90214.96828280001
# Entered trade at 146.45 for 3661.2499999999995 at 2024-06-13 09:15:00
# Exiting trade at 116.496 at 2024-06-13 09:30:00
# Account Balance: 93072.957677935
# Exiting trade at 95.80799999999999 at 2024-06-13 09:30:00
# Account Balance: 95415.02757191501
# Exiting trade at 140.59199999999998 at 2024-06-13 09:30:00
# Account Balance: 98873.92552756
# Entering 3 trades at 2024-06-13 10:00:00
# Account Balance: 96046.42552756
# Entered trade at 113.1 for 2827.5 at 2024-06-13 10:00:00
# Account Balance: 92666.42552756
# Entered trade at 135.2 for 3379.9999999999995 at 2024-06-13 10:00:00
# Account Balance: 90373.92552756
# Entered trade at 91.7 for 2292.5 at 2024-06-13 10:00:00
# Exiting trade at 113.1 at 2024-06-13 10:01:00
# Account Balance: 93147.29758706
# Exiting trade at 135.2 at 2024-06-13 10:01:00
# Account Balance: 96471.81591106001
# Exiting trade at 91.7 at 2024-06-13 10:01:00
# Account Balance: 98711.49882756
# Entering 7 trades at 2024-06-14 04:30:00
# Account Balance: 95693.99882756
# Entered trade at 120.7 for 3017.5 at 2024-06-14 04:30:00
# Account Balance: 94492.74882756
# Entered trade at 48.05 for 1201.25 at 2024-06-14 04:30:00
# Account Balance: 92910.24882756
# Entered trade at 63.3 for 1582.5 at 2024-06-14 04:30:00
# Account Balance: 90860.24882756
# Entered trade at 82.0 for 2050.0 at 2024-06-14 04:30:00
# Account Balance: 87625.24882756
# Entered trade at 129.4 for 3235.0 at 2024-06-14 04:30:00
# Account Balance: 85153.99882756
# Entered trade at 98.85 for 2471.25 at 2024-06-14 04:30:00
# Account Balance: 83202.74882756
# Entered trade at 78.05 for 1951.25 at 2024-06-14 04:30:00
# Exiting trade at 179.843 at 2024-06-14 04:45:00
# Account Balance: 87641.5170160775
# Exiting trade at 55.73799999999999 at 2024-06-14 04:45:00
# Account Balance: 88984.4710071075
# Exiting trade at 73.428 at 2024-06-14 04:45:00
# Account Balance: 90768.62891828749
# Exiting trade at 95.11999999999999 at 2024-06-14 04:45:00
# Account Balance: 93093.80409548749
# Exiting trade at 150.10399999999998 at 2024-06-14 04:45:00
# Account Balance: 96790.32785072748
# Exiting trade at 147.2865 at 2024-06-14 04:45:00
# Account Balance: 100417.01314844874
# Exiting trade at 116.2945 at 2024-06-14 04:45:00
# Account Balance: 103270.64013364998
# Entering 3 trades at 2024-06-14 05:30:00
# Account Balance: 91120.64013364998
# Entered trade at 486.0 for 12150.0 at 2024-06-14 05:30:00
# Account Balance: 77344.39013364998
# Entered trade at 551.05 for 13776.249999999998 at 2024-06-14 05:30:00
# Account Balance: 61644.390133649984
# Entered trade at 628.0 for 15700.0 at 2024-06-14 05:30:00
# Exiting trade at 466.56 at 2024-06-14 05:45:00
# Account Balance: 73232.31206224998
# Exiting trade at 529.0079999999999 at 2024-06-14 05:45:00
# Account Balance: 86377.56872635498
# Entering 4 trades at 2024-06-14 06:00:00
# Account Balance: 81771.31872635498
# Entered trade at 184.25 for 4606.25 at 2024-06-14 06:00:00
# Account Balance: 79116.31872635498
# Entered trade at 106.2 for 2655.0 at 2024-06-14 06:00:00
# Account Balance: 75233.81872635498
# Entered trade at 155.3 for 3882.5000000000005 at 2024-06-14 06:00:00
# Account Balance: 69785.06872635498
# Entered trade at 217.95 for 5448.75 at 2024-06-14 06:00:00
# Exiting trade at 176.88 at 2024-06-14 06:15:00
# Account Balance: 74148.92060977998
# Exiting trade at 101.952 at 2024-06-14 06:15:00
# Account Balance: 76644.21021639998
# Exiting trade at 149.088 at 2024-06-14 06:15:00
# Account Balance: 80314.98230592998
# Exiting trade at 209.23199999999997 at 2024-06-14 06:15:00
# Account Balance: 85485.63173872499
# Exiting trade at 602.88 at 2024-06-14 09:30:00
# Account Balance: 100473.11604152499
# Entering 3 trades at 2024-06-18 04:15:00
# Account Balance: 97750.61604152499
# Entered trade at 108.9 for 2722.5 at 2024-06-18 04:15:00
# Account Balance: 95720.61604152499
# Entered trade at 81.2 for 2030.0 at 2024-06-18 04:15:00
# Account Balance: 94213.11604152499
# Entered trade at 60.3 for 1507.5 at 2024-06-18 04:15:00
# Exiting trade at 104.544 at 2024-06-18 04:45:00
# Account Balance: 96773.04521441499
# Exiting trade at 77.952 at 2024-06-18 04:45:00
# Account Balance: 98669.82031853498
# Exiting trade at 57.888 at 2024-06-18 04:45:00
# Account Balance: 100066.23729856499
# Entering 5 trades at 2024-06-18 05:00:00
# Account Balance: 87536.23729856499
# Entered trade at 501.2 for 12530.0 at 2024-06-18 05:00:00
# Account Balance: 77061.23729856499
# Entered trade at 419.0 for 10475.0 at 2024-06-18 05:00:00
# Account Balance: 75349.98729856499
# Entered trade at 68.45 for 1711.25 at 2024-06-18 05:00:00
# Account Balance: 73137.48729856499
# Entered trade at 88.5 for 2212.5 at 2024-06-18 05:00:00
# Account Balance: 70301.23729856499
# Entered trade at 113.45 for 2836.25 at 2024-06-18 05:00:00
# Exiting trade at 481.152 at 2024-06-18 05:15:00
# Account Balance: 82253.05604468498
# Exiting trade at 402.24 at 2024-06-18 05:15:00
# Account Balance: 92236.95910658498
# Exiting trade at 65.712 at 2024-06-18 05:15:00
# Account Balance: 93828.49181442999
# Exiting trade at 84.96 at 2024-06-18 05:15:00
# Account Balance: 95900.03315327999
# Exiting trade at 108.91199999999999 at 2024-06-18 05:15:00
# Account Balance: 98568.891965625
# Entering 2 trades at 2024-06-18 05:15:00
# Account Balance: 96958.891965625
# Entered trade at 64.4 for 1610.0000000000002 at 2024-06-18 05:15:00
# Account Balance: 96057.641965625
# Entered trade at 36.05 for 901.2499999999999 at 2024-06-18 05:15:00
# Exiting trade at 61.824000000000005 at 2024-06-18 05:30:00
# Account Balance: 97552.215324065
# Exiting trade at 34.608 at 2024-06-18 05:30:00
# Account Balance: 98368.07323667
# Entering 3 trades at 2024-06-18 06:00:00
# Account Balance: 88868.07323667
# Entered trade at 380.0 for 9500.0 at 2024-06-18 06:00:00
# Account Balance: 82726.82323667
# Entered trade at 245.65 for 6141.25 at 2024-06-18 06:00:00
# Account Balance: 75045.57323667
# Entered trade at 307.25 for 7681.25 at 2024-06-18 06:00:00
# Exiting trade at 364.8 at 2024-06-18 06:15:00
# Account Balance: 84095.79367467
# Exiting trade at 235.82399999999998 at 2024-06-18 06:15:00
# Account Balance: 89929.597176235
# Exiting trade at 294.96 at 2024-06-18 06:15:00
# Account Balance: 97238.14041195999
# Entering 3 trades at 2024-06-19 04:30:00
# Account Balance: 95836.89041195999
# Entered trade at 56.05 for 1401.25 at 2024-06-19 04:30:00
# Account Balance: 93943.14041195999
# Entered trade at 75.75 for 1893.75 at 2024-06-19 04:30:00
# Account Balance: 93188.14041195999
# Entered trade at 30.2 for 755.0 at 2024-06-19 04:30:00
# Exiting trade at 65.01799999999999 at 2024-06-19 04:45:00
# Account Balance: 94762.54563978998
# Exiting trade at 87.86999999999999 at 2024-06-19 04:45:00
# Account Balance: 96906.89953823999
# Exiting trade at 35.032 at 2024-06-19 04:45:00
# Account Balance: 97733.42795715999
# Entering 3 trades at 2024-06-19 05:00:00
# Account Balance: 96037.17795715999
# Entered trade at 67.85 for 1696.2499999999998 at 2024-06-19 05:00:00
# Account Balance: 94748.42795715999
# Entered trade at 51.55 for 1288.75 at 2024-06-19 05:00:00
# Account Balance: 92442.17795715999
# Entered trade at 92.25 for 2306.25 at 2024-06-19 05:00:00
# Exiting trade at 65.136 at 2024-06-19 05:15:00
# Account Balance: 94019.346316945
# Exiting trade at 49.48799999999999 at 2024-06-19 05:15:00
# Account Balance: 95206.28322109999
# Exiting trade at 88.56 at 2024-06-19 05:15:00
# Account Balance: 97367.60173532499
# Entering 3 trades at 2024-06-19 05:30:00
# Account Balance: 95336.35173532499
# Entered trade at 81.25 for 2031.25 at 2024-06-19 05:30:00
# Account Balance: 91793.85173532499
# Entered trade at 141.7 for 3542.4999999999995 at 2024-06-19 05:30:00
# Account Balance: 90322.60173532499
# Entered trade at 58.85 for 1471.25 at 2024-06-19 05:30:00
# Exiting trade at 78.0 at 2024-06-19 05:45:00
# Account Balance: 92220.57386845
# Exiting trade at 136.03199999999998 at 2024-06-19 05:45:00
# Account Balance: 95565.75406862
# Exiting trade at 56.496 at 2024-06-19 05:45:00
# Account Balance: 96927.457207505
# Entering 4 trades at 2024-06-19 06:00:00
# Account Balance: 93656.207207505
# Entered trade at 130.85 for 3271.25 at 2024-06-19 06:00:00
# Account Balance: 91836.207207505
# Entered trade at 72.8 for 1820.0 at 2024-06-19 06:00:00
# Account Balance: 90529.957207505
# Entered trade at 52.25 for 1306.25 at 2024-06-19 06:00:00
# Account Balance: 89624.957207505
# Entered trade at 36.2 for 905.0000000000001 at 2024-06-19 06:00:00
# Exiting trade at 151.78599999999997 at 2024-06-19 06:15:00
# Account Balance: 93363.43149941499
# Exiting trade at 84.448 at 2024-06-19 06:15:00
# Account Balance: 95422.437754295
# Exiting trade at 60.60999999999999 at 2024-06-19 06:15:00
# Account Balance: 96886.90364464499
# Exiting trade at 41.992 at 2024-06-19 06:15:00
# Account Balance: 97887.02049116499
# Entering 1 trades at 2024-06-19 09:30:00
# Account Balance: 95269.52049116499
# Entered trade at 104.7 for 2617.5 at 2024-06-19 09:30:00
# Exiting trade at 121.452 at 2024-06-19 09:45:00
# Account Balance: 98251.438552785
# Entering 4 trades at 2024-06-20 05:00:00
# Account Balance: 97692.688552785
# Entered trade at 22.35 for 558.75 at 2024-06-20 05:00:00
# Account Balance: 96822.688552785
# Entered trade at 34.8 for 869.9999999999999 at 2024-06-20 05:00:00
# Account Balance: 93688.938552785
# Entered trade at 125.35 for 3133.75 at 2024-06-20 05:00:00
# Account Balance: 92342.688552785
# Entered trade at 53.85 for 1346.25 at 2024-06-20 05:00:00
# Exiting trade at 21.456 at 2024-06-20 05:15:00
# Account Balance: 92830.56051802
# Exiting trade at 33.407999999999994 at 2024-06-20 05:15:00
# Account Balance: 93616.49270549999
# Exiting trade at 120.33599999999998 at 2024-06-20 05:15:00
# Account Balance: 96570.244421035
# Exiting trade at 51.696 at 2024-06-20 05:15:00
# Account Balance: 97812.24465941999
# Entering 1 trades at 2024-06-20 05:45:00
# Account Balance: 96959.74465941999
# Entered trade at 34.1 for 852.5 at 2024-06-20 05:45:00
# Exiting trade at 32.736 at 2024-06-20 06:00:00
# Account Balance: 97728.91844082999
# Entering 1 trades at 2024-06-20 06:30:00
# Account Balance: 97593.91844082999
# Entered trade at 5.4 for 135.0 at 2024-06-20 06:30:00
# Exiting trade at 6.264 at 2024-06-20 06:45:00
# Account Balance: 97702.94802566999
# Entering 2 trades at 2024-06-20 06:45:00
# Account Balance: 97332.94802566999
# Entered trade at 14.8 for 370.0 at 2024-06-20 06:45:00
# Account Balance: 95755.44802566999
# Entered trade at 63.1 for 1577.5 at 2024-06-20 06:45:00
# Exiting trade at 17.168 at 2024-06-20 07:00:00
# Account Balance: 96136.43281374998
# Exiting trade at 73.196 at 2024-06-20 07:00:00
# Account Balance: 97914.80444400998
# Entering 1 trades at 2024-06-20 07:00:00
# Account Balance: 97116.05444400998
# Entered trade at 31.95 for 798.75 at 2024-06-20 07:00:00
# Exiting trade at 37.062 at 2024-06-20 07:15:00
# Account Balance: 97993.21282097997
# Entering 4 trades at 2024-06-20 08:15:00
# Account Balance: 95091.96282097997
# Entered trade at 116.05 for 2901.25 at 2024-06-20 08:15:00
# Account Balance: 87109.46282097997
# Entered trade at 319.3 for 7982.5 at 2024-06-20 08:15:00
# Account Balance: 80096.96282097997
# Entered trade at 280.5 for 7012.5 at 2024-06-20 08:15:00
# Account Balance: 74736.96282097997
# Entered trade at 214.4 for 5360.0 at 2024-06-20 08:15:00
# Exiting trade at 131.13649999999998 at 2024-06-20 08:30:00
# Account Balance: 77960.37454732622
# Entering 2 trades at 2024-06-20 08:30:00
# Account Balance: 76090.37454732622
# Entered trade at 74.8 for 1870.0 at 2024-06-20 08:30:00
# Account Balance: 68810.37454732622
# Entered trade at 291.2 for 7280.0 at 2024-06-20 08:30:00
# Exiting trade at 306.528 at 2024-06-20 08:45:00
# Account Balance: 76407.40177325622
# Exiting trade at 269.28 at 2024-06-20 08:45:00
# Account Balance: 83075.53449130621
# Exiting trade at 205.82399999999998 at 2024-06-20 08:45:00
# Account Balance: 88161.19486474621
# Exiting trade at 71.80799999999999 at 2024-06-20 08:45:00
# Account Balance: 89904.75025622621
# Exiting trade at 279.55199999999996 at 2024-06-20 08:45:00
# Account Balance: 96829.0471813462
# Entering 5 trades at 2024-06-21 04:30:00
# Account Balance: 91679.0471813462
# Entered trade at 206.0 for 5150.0 at 2024-06-21 04:30:00
# Account Balance: 84554.0471813462
# Entered trade at 285.0 for 7125.0 at 2024-06-21 04:30:00
# Account Balance: 82794.0471813462
# Entered trade at 70.4 for 1760.0000000000002 at 2024-06-21 04:30:00
# Account Balance: 76747.7971813462
# Entered trade at 241.85 for 6046.25 at 2024-06-21 04:30:00
# Account Balance: 72459.0471813462
# Entered trade at 171.55 for 4288.75 at 2024-06-21 04:30:00
# Exiting trade at 197.76 at 2024-06-21 04:45:00
# Account Balance: 77343.6066819462
# Exiting trade at 273.59999999999997 at 2024-06-21 04:45:00
# Account Balance: 84119.4720104462
# Exiting trade at 68.288 at 2024-06-21 04:45:00
# Account Balance: 85775.2565517262
# Exiting trade at 232.176 at 2024-06-21 04:45:00
# Account Balance: 91518.0858489112
# Exiting trade at 164.68800000000002 at 2024-06-21 04:45:00
# Account Balance: 95577.8923650662
# Entering 2 trades at 2024-06-21 04:45:00
# Account Balance: 93227.8923650662
# Entered trade at 94.0 for 2350.0 at 2024-06-21 04:45:00
# Account Balance: 91641.6423650662
# Entered trade at 63.45 for 1586.25 at 2024-06-21 04:45:00
# Exiting trade at 90.24 at 2024-06-21 05:00:00
# ...
# Entered trade at 356.55 for 8913.75 at 2024-07-11 04:15:00
# Account Balance: 84886.30491726386
# Entered trade at 266.75 for 6668.75 at 2024-07-11 04:15:00
# Exiting trade at 62.747499999999995 at 2024-07-11 04:18:00
# Account Balance: 86403.8980349576
# Exiting trade at 371.856 at 2024-07-11 04:19:00
# Account Balance: 95630.0817366926
# Exiting trade at 479.03999999999996 at 2024-07-11 04:19:00
# Account Balance: 107529.23120659261
# Exiting trade at 128.8675 at 2024-07-11 04:20:00
# Account Balance: 110695.72062998636
# Exiting trade at 447.168 at 2024-07-11 04:30:00
# Account Balance: 121800.04284056636
# Exiting trade at 209.08999999999997 at 2024-07-11 04:30:00
# Account Balance: 126967.72851971636
# Exiting trade at 506.88 at 2024-07-11 04:30:00
# Account Balance: 139561.15481251635
# Exiting trade at 392.688 at 2024-07-11 04:30:00
# Account Balance: 149306.84910242134
# Exiting trade at 342.288 at 2024-07-11 04:30:00
# Account Balance: 157795.66293707635
# Exiting trade at 256.08 at 2024-07-11 04:30:00
# Account Balance: 164134.61267875135
# Entering 9 trades at 2024-07-11 04:30:00
# Account Balance: 156059.61267875135
# Entered trade at 323.0 for 8075.0 at 2024-07-11 04:30:00
# Account Balance: 155440.86267875135
# Entered trade at 24.75 for 618.75 at 2024-07-11 04:30:00
# Account Balance: 143094.61267875135
# Entered trade at 493.85 for 12346.25 at 2024-07-11 04:30:00
# Account Balance: 140649.61267875135
# Entered trade at 97.8 for 2445.0 at 2024-07-11 04:30:00
# Account Balance: 126674.61267875135
# Entered trade at 559.0 for 13975.0 at 2024-07-11 04:30:00
# Account Balance: 120793.36267875135
# Entered trade at 235.25 for 5881.25 at 2024-07-11 04:30:00
# Account Balance: 117208.36267875135
# Entered trade at 143.4 for 3585.0 at 2024-07-11 04:30:00
# Account Balance: 115029.61267875135
# Entered trade at 87.15 for 2178.75 at 2024-07-11 04:30:00
# Account Balance: 105650.86267875135
# Entered trade at 375.15 for 9378.75 at 2024-07-11 04:30:00
# Exiting trade at 310.08 at 2024-07-11 04:45:00
# Account Balance: 113336.47005105135
# Exiting trade at 24.0075 at 2024-07-11 04:45:00
# Account Balance: 113887.9755538451
# Exiting trade at 474.096 at 2024-07-11 04:45:00
# Account Balance: 125663.8310362301
# Exiting trade at 94.866 at 2024-07-11 04:45:00
# Account Balance: 127982.4249018151
# Exiting trade at 536.64 at 2024-07-11 04:45:00
# Account Balance: 141318.0091777151
# Exiting trade at 225.84 at 2024-07-11 04:45:00
# Account Balance: 146902.83064624012
# Exiting trade at 139.098 at 2024-07-11 04:45:00
# Account Balance: 150324.49404424513
# Exiting trade at 101.094 at 2024-07-11 04:45:00
# Account Balance: 152798.66595513513
# Exiting trade at 360.14399999999995 at 2024-07-11 04:45:00
# Account Balance: 161732.77457965014
# Entering 9 trades at 2024-07-11 04:45:00
# Account Balance: 155489.02457965014
# Entered trade at 249.75 for 6243.75 at 2024-07-11 04:45:00
# Account Balance: 152461.52457965014
# Entered trade at 121.1 for 3027.5 at 2024-07-11 04:45:00
# Account Balance: 144040.27457965014
# Entered trade at 336.85 for 8421.25 at 2024-07-11 04:45:00
# Account Balance: 142547.77457965014
# Entered trade at 59.7 for 1492.5 at 2024-07-11 04:45:00
# Account Balance: 131390.27457965014
# Entered trade at 446.3 for 11157.5 at 2024-07-11 04:45:00
# Account Balance: 128891.52457965014
# Entered trade at 99.95 for 2498.75 at 2024-07-11 04:45:00
# Account Balance: 116167.77457965014
# Entered trade at 508.95 for 12723.75 at 2024-07-11 04:45:00
# Account Balance: 106394.02457965014
# Entered trade at 390.95 for 9773.75 at 2024-07-11 04:45:00
# Account Balance: 104739.02457965014
# Entered trade at 66.2 for 1655.0 at 2024-07-11 04:45:00
# Exiting trade at 372.1275 at 2024-07-11 05:00:00
# Account Balance: 113974.09926964389
# Exiting trade at 136.843 at 2024-07-11 05:00:00
# Account Balance: 117339.8340396614
# Exiting trade at 501.90650000000005 at 2024-07-11 05:00:00
# Account Balance: 129812.09041333264
# Exiting trade at 69.252 at 2024-07-11 05:00:00
# Account Balance: 131492.09526795265
# Exiting trade at 664.987 at 2024-07-11 05:00:00
# Account Balance: 148032.19934861016
# Exiting trade at 112.94349999999999 at 2024-07-11 05:00:00
# Account Balance: 150801.8683020639
# Exiting trade at 758.3355 at 2024-07-11 05:00:00
# Account Balance: 169670.43888653765
# Exiting trade at 582.5155 at 2024-07-11 05:00:00
# Account Balance: 184153.39019806142
# Exiting trade at 74.806 at 2024-07-11 05:00:00
# Account Balance: 185971.8902952964
# Entering 1 trades at 2024-07-11 05:30:00
# Account Balance: 185933.1402952964
# Entered trade at 1.55 for 38.75 at 2024-07-11 05:30:00
# Exiting trade at 1.7979999999999998 at 2024-07-11 05:45:00
# Account Balance: 185930.7839724264
# Entering 4 trades at 2024-07-11 05:45:00
# Account Balance: 185822.0339724264
# Entered trade at 4.35 for 108.74999999999999 at 2024-07-11 05:45:00
# Account Balance: 185142.0339724264
# Entered trade at 27.2 for 680.0 at 2024-07-11 05:45:00
# Account Balance: 184798.2839724264
# Entered trade at 13.75 for 343.75 at 2024-07-11 05:45:00
# Account Balance: 184614.5339724264
# Entered trade at 7.35 for 183.75 at 2024-07-11 05:45:00
# Exiting trade at 5.045999999999999 at 2024-07-11 06:00:00
# Account Balance: 184693.18558243642
# Exiting trade at 31.551999999999996 at 2024-07-11 06:00:00
# Account Balance: 185432.91978755643
# Exiting trade at 15.95 at 2024-07-11 06:00:00
# Account Balance: 185783.52660080642
# Exiting trade at 8.526 at 2024-07-11 06:00:00
# Account Balance: 185948.97242461643
# Entering 10 trades at 2024-07-11 06:00:00
# Account Balance: 180475.22242461643
# Entered trade at 218.95 for 5473.75 at 2024-07-11 06:00:00
# Account Balance: 177632.72242461643
# Entered trade at 113.7 for 2842.5 at 2024-07-11 06:00:00
# Account Balance: 174320.22242461643
# Entered trade at 132.5 for 3312.5 at 2024-07-11 06:00:00
# Account Balance: 170232.72242461643
# Entered trade at 163.5 for 4087.5 at 2024-07-11 06:00:00
# Account Balance: 161565.22242461643
# Entered trade at 346.7 for 8667.5 at 2024-07-11 06:00:00
# Account Balance: 160320.22242461643
# Entered trade at 49.8 for 1245.0 at 2024-07-11 06:00:00
# Account Balance: 155657.72242461643
# Entered trade at 186.5 for 4662.5 at 2024-07-11 06:00:00
# Account Balance: 153745.22242461643
# Entered trade at 76.5 for 1912.5 at 2024-07-11 06:00:00
# Account Balance: 153451.47242461643
# Entered trade at 11.75 for 293.75 at 2024-07-11 06:00:00
# Account Balance: 146000.22242461643
# Entered trade at 298.05 for 7451.25 at 2024-07-11 06:00:00
# Exiting trade at 210.19199999999998 at 2024-07-11 06:30:00
# Account Balance: 151194.81243751143
# Exiting trade at 110.289 at 2024-07-11 06:30:00
# Account Balance: 153898.0292321639
# Exiting trade at 127.19999999999999 at 2024-07-11 06:30:00
# Account Balance: 157022.95609541392
# Exiting trade at 158.595 at 2024-07-11 06:30:00
# Account Balance: 160930.84093205142
# Exiting trade at 332.832 at 2024-07-11 06:30:00
# Account Balance: 169183.8400527214
# Exiting trade at 48.306 at 2024-07-11 06:30:00
# Account Balance: 170341.30809470642
# Exiting trade at 179.04 at 2024-07-11 06:30:00
# Account Balance: 174759.02628335642
# Exiting trade at 74.205 at 2024-07-11 06:30:00
# Account Balance: 176562.3705647189
# Exiting trade at 11.397499999999999 at 2024-07-11 06:30:00
# Account Balance: 176799.40449028765
# Exiting trade at 286.128 at 2024-07-11 06:30:00
# Account Balance: 183887.69438909265
# Entering 4 trades at 2024-07-11 09:45:00
# Account Balance: 183886.44438909265
# Entered trade at 0.05 for 1.25 at 2024-07-11 09:45:00
# Account Balance: 181855.19438909265
# Entered trade at 81.25 for 2031.25 at 2024-07-11 09:45:00
# Account Balance: 180590.19438909265
# Entered trade at 50.6 for 1265.0 at 2024-07-11 09:45:00
# Account Balance: 176052.69438909265
# Entered trade at 181.5 for 4537.5 at 2024-07-11 09:45:00
# Exiting trade at 184.0 at 2024-07-11 10:00:00
# Account Balance: 180594.26191284266
# Entering 6 trades at 2024-07-11 10:00:00
# Account Balance: 171294.26191284266
# Entered trade at 372.0 for 9300.0 at 2024-07-11 10:00:00
# Account Balance: 169494.26191284266
# Entered trade at 72.0 for 1800.0 at 2024-07-11 10:00:00
# Account Balance: 162594.26191284266
# Entered trade at 276.0 for 6900.0 at 2024-07-11 10:00:00
# Account Balance: 158419.26191284266
# Entered trade at 167.0 for 4175.0 at 2024-07-11 10:00:00
# Account Balance: 150428.01191284266
# Entered trade at 319.65 for 7991.249999999999 at 2024-07-11 10:00:00
# Account Balance: 144553.01191284266
# Entered trade at 235.0 for 5875.0 at 2024-07-11 10:00:00
# Exiting trade at 0.05 at 2024-07-11 10:01:00
# Account Balance: 144507.05885009267
# Exiting trade at 83.95 at 2024-07-11 10:01:00
# Account Balance: 146553.50801209267
# Exiting trade at 46.6 at 2024-07-11 10:01:00
# Account Balance: 147668.39201909266
# Exiting trade at 319.65 at 2024-07-11 10:01:00
# Account Balance: 155592.86185834266
# Exiting trade at 372.85 at 2024-07-11 10:16:00
# Account Balance: 164844.08600246767
# Exiting trade at 72.0 at 2024-07-11 10:16:00
# Account Balance: 166592.47564246767
# Exiting trade at 272.0 at 2024-07-11 10:16:00
# Account Balance: 173328.55277246766
# Exiting trade at 166.6 at 2024-07-11 10:16:00
# Account Balance: 177436.14153846767
# Exiting trade at 235.0 at 2024-07-11 10:16:00
# Account Balance: 183249.54661346765
# Entering 20 trades at 2024-07-12 04:05:00
# Account Balance: 178695.79661346765
# Entered trade at 182.15 for 4553.75 at 2024-07-12 04:05:00
# Account Balance: 171794.54661346765
# Entered trade at 276.05 for 6901.25 at 2024-07-12 04:05:00
# Account Balance: 163697.04661346765
# Entered trade at 323.9 for 8097.499999999999 at 2024-07-12 04:05:00
# Account Balance: 157378.29661346765
# Entered trade at 252.75 for 6318.75 at 2024-07-12 04:05:00
# Account Balance: 154308.29661346765
# Entered trade at 122.8 for 3070.0 at 2024-07-12 04:05:00
# Account Balance: 153902.04661346765
# Entered trade at 16.25 for 406.25 at 2024-07-12 04:05:00
# Account Balance: 152642.04661346765
# Entered trade at 50.4 for 1260.0 at 2024-07-12 04:05:00
# Account Balance: 145379.54661346765
# Entered trade at 290.5 for 7262.5 at 2024-07-12 04:05:00
# Account Balance: 140487.04661346765
# Entered trade at 195.7 for 4892.5 at 2024-07-12 04:05:00
# Account Balance: 138518.29661346765
# Entered trade at 78.75 for 1968.75 at 2024-07-12 04:05:00
# Account Balance: 135508.29661346765
# Entered trade at 120.4 for 3010.0 at 2024-07-12 04:05:00
# Account Balance: 126922.04661346765
# Entered trade at 343.45 for 8586.25 at 2024-07-12 04:05:00
# Account Balance: 115324.54661346765
# Entered trade at 463.9 for 11597.5 at 2024-07-12 04:05:00
# Account Balance: 101994.54661346765
# Entered trade at 533.2 for 13330.000000000002 at 2024-07-12 04:05:00
# Account Balance: 100245.79661346765
# Entered trade at 69.95 for 1748.75 at 2024-07-12 04:05:00
# Account Balance: 97399.54661346765
# Entered trade at 113.85 for 2846.25 at 2024-07-12 04:05:00
# Account Balance: 93120.79661346765
# Entered trade at 171.15 for 4278.75 at 2024-07-12 04:05:00
# Account Balance: 87095.79661346765
# Entered trade at 241.0 for 6025.0 at 2024-07-12 04:05:00
# Account Balance: 84642.04661346765
# Entered trade at 98.15 for 2453.75 at 2024-07-12 04:05:00
# Account Balance: 79588.29661346765
# Entered trade at 202.15 for 5053.75 at 2024-07-12 04:05:00
# Exiting trade at 265.008 at 2024-07-12 04:06:00
# Account Balance: 86149.89375007265
# Exiting trade at 310.94399999999996 at 2024-07-12 04:06:00
# Account Balance: 93857.04764446264
# Exiting trade at 47.879999999999995 at 2024-07-12 04:06:00
# Account Balance: 95003.87600376263
# Exiting trade at 187.87199999999999 at 2024-07-12 04:06:00
# Account Balance: 99641.84752933263
# Exiting trade at 74.8125 at 2024-07-12 04:06:00
# Account Balance: 101460.31684073889
# Exiting trade at 114.38 at 2024-07-12 04:06:00
# Account Balance: 104265.51792128889
# Exiting trade at 93.2425 at 2024-07-12 04:06:00
# Account Balance: 106543.59338687014
# Entering 4 trades at 2024-07-12 04:15:00
# Account Balance: 105778.59338687014
# Entered trade at 30.6 for 765.0 at 2024-07-12 04:15:00
# Account Balance: 104566.09338687014
# Entered trade at 48.5 for 1212.5 at 2024-07-12 04:15:00
# Account Balance: 99531.09338687014
# Entered trade at 201.4 for 5035.0 at 2024-07-12 04:15:00
# Account Balance: 95334.84338687014
# Entered trade at 167.85 for 4196.25 at 2024-07-12 04:15:00
# Exiting trade at 15.4375 at 2024-07-12 04:25:00
# Account Balance: 95672.62276858889
# Exiting trade at 173.0425 at 2024-07-12 04:26:00
# Account Balance: 99940.74549967014
# Exiting trade at 240.11249999999998 at 2024-07-12 04:26:00
# Account Balance: 105881.45557532638
# Exiting trade at 116.66 at 2024-07-12 04:26:00
# Account Balance: 108743.51514917638
# Exiting trade at 278.88 at 2024-07-12 04:26:00
# Account Balance: 115651.05366822638
# Exiting trade at 329.712 at 2024-07-12 04:26:00
# Account Balance: 123826.24590357138
# Exiting trade at 194.064 at 2024-07-12 04:26:00
# Account Balance: 128618.63417078639
# Exiting trade at 34.577999999999996 at 2024-07-12 04:30:00
# Account Balance: 129433.82726709139
# Exiting trade at 54.80499999999999 at 2024-07-12 04:30:00
# Account Balance: 130753.49214195389
# Exiting trade at 300.086 at 2024-07-12 04:30:00
# Account Balance: 138191.57791798888
# Exiting trade at 250.0965 at 2024-07-12 04:30:00
# Account Balance: 144382.73550243513
# Entering 6 trades at 2024-07-12 04:30:00
# Account Balance: 142033.98550243513
# Entered trade at 93.95 for 2348.75 at 2024-07-12 04:30:00
# Account Balance: 137991.48550243513
# Entered trade at 161.7 for 4042.4999999999995 at 2024-07-12 04:30:00
# Account Balance: 135243.98550243513
# Entered trade at 109.9 for 2747.5 at 2024-07-12 04:30:00
# Account Balance: 133451.48550243513
# Entered trade at 71.7 for 1792.5 at 2024-07-12 04:30:00
# Account Balance: 132306.48550243513
# Entered trade at 45.8 for 1145.0 at 2024-07-12 04:30:00
# Account Balance: 129430.23550243513
# Entered trade at 115.05 for 2876.25 at 2024-07-12 04:30:00
# Exiting trade at 91.1315 at 2024-07-12 04:45:00
# Account Balance: 131655.69740091887
# Exiting trade at 155.23199999999997 at 2024-07-12 04:45:00
# Account Balance: 135479.68920308887
# Exiting trade at 105.504 at 2024-07-12 04:45:00
# Account Balance: 138063.55895607886
# Exiting trade at 68.832 at 2024-07-12 04:45:00
# Account Balance: 139732.89854924887
# Exiting trade at 43.967999999999996 at 2024-07-12 04:45:00
# Account Balance: 140782.17711782886
# Exiting trade at 111.59849999999999 at 2024-07-12 04:45:00
# Account Balance: 143518.05057627012
# Exiting trade at 160.885 at 2024-07-12 05:31:00
# Account Balance: 147484.51891855762
# Entering 2 trades at 2024-07-12 05:45:00
# Account Balance: 146309.51891855762
# Entered trade at 47.0 for 1175.0 at 2024-07-12 05:45:00
# Account Balance: 145529.51891855762
# Entered trade at 31.2 for 780.0 at 2024-07-12 05:45:00
# Exiting trade at 54.519999999999996 at 2024-07-12 06:00:00
# Account Balance: 146842.09493475762
# Entering 2 trades at 2024-07-12 06:00:00
# Account Balance: 143938.34493475762
# Entered trade at 116.15 for 2903.75 at 2024-07-12 06:00:00
# Account Balance: 141989.59493475762
# Entered trade at 77.95 for 1948.75 at 2024-07-12 06:00:00
# Exiting trade at 111.504 at 2024-07-12 06:15:00
# Account Balance: 144723.09331337264
# Exiting trade at 74.832 at 2024-07-12 06:15:00
# Account Balance: 146542.06153216763
# Exiting trade at 29.951999999999998 at 2024-07-12 06:30:00
# Account Balance: 147241.80763128764
# Exiting trade at 445.34399999999994 at 2024-07-12 09:41:00
# Account Balance: 158300.64273967763
# Exiting trade at 511.872 at 2024-07-12 09:41:00
# Account Balance: 171018.56004899764
# Exiting trade at 267.0 at 2024-07-12 09:59:00
# Account Balance: 177631.47889737264
# Exiting trade at 353.65 at 2024-07-12 09:59:00
# Account Balance: 186405.59834199763
# Exiting trade at 192.2 at 2024-07-12 10:00:00
# Account Balance: 191152.82995812263
# Total trades executed: 789
# Total missed trades: 28
# Live trading simulation complete.
# Final summary statistics:
#    Total Trades  Total Missed Trades  Total Profit  Max Drawdown   Best Trade  \
# 0           789                   28  91152.829958  16218.975503  9463.157219
#
#    Worst Trade
# 0  -1127.91424
# Final Balance: 191152.82995812263
# Max Drawdown: 16218.975503199996
# Best Trade: 9463.157218775004
# Worst Trade: -1127.9142399900022
# Total Trades: 789
# Total Missed Trades: 28
# Total Profit: 91152.8299581224
# Total Profitable Trades: 204
# Analysis and visualization complete.
