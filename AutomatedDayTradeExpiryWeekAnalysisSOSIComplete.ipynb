# %% [markdown]
# All SOSI 1 min buy data in one file.

# %%
from datetime import timedelta
from datetime import datetime
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Function to filter buy signals from the 1-minute chart data
def filter_signals(data):
    if 'Buy Signal SOSI Final' not in data.columns:
        print("Warning: 'Buy Signal SOSI Final' column not found in the data.")
        if 'volume' and 'Volume' not in data.columns:
            print("Error: 'volume' column not found in the data.")
            return pd.DataFrame()
        data = calculate_indicators(data)
        if 'Buy Signal SOSI Final' not in data.columns:
            print("Error: 'Buy Signal SOSI Final' column still not found in the data.")
            return pd.DataFrame()
        buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
        return buy_signals

    buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
    return buy_signals

# Function to calculate indicators and buy signals
def calculate_indicators(data):
    # Calculate VWPCI
    if 'volume' in data.columns:
        volume = data['volume']
    elif 'Volume' in data.columns:
        volume = data['Volume']
    else:
        print("Error: 'volume' column not found in the data.")
        return data
    data['priceChangeRatio'] = (data['close'] - data['open']) / (data['high'] - data['low'])
    data['VWPCI'] = data['priceChangeRatio'] * volume

    # Convert Unix timestamp (UTC) to datetime
    data['time_utc'] = pd.to_datetime(data['time'], unit='s', utc=True)

    # Convert UTC to IST
    data['time_ist'] = data['time_utc'] + timedelta(hours=5, minutes=30)

    # Calculate ROC
    roc_periods = 14
    data['ROC'] = data['close'].pct_change(periods=roc_periods)

    # Calculate MVI
    data['MVI'] = volume * ((data['close'] - data['open']) / data['close'])

    # Calculate VOLD
    data['up_volume'] = np.where(data['close'] > data['close'].shift(1), volume, 0)
    data['down_volume'] = np.where(data['close'] <= data['close'].shift(1), volume, 0)
    data['total_up_volume'] = data['up_volume'].cumsum()
    data['total_down_volume'] = data['down_volume'].cumsum()
    data['VOLD_ratio'] = data['total_up_volume'] / data['total_down_volume']

    # Normalize VOLD
    data['normalized_vold'] = (data['VOLD_ratio'] - data['VOLD_ratio'].rolling(window=100).min()) / \
                              (data['VOLD_ratio'].rolling(window=100).max() - data['VOLD_ratio'].rolling(window=100).min())

    # Theta Calculation
    days_to_expiration = 30  # assuming a constant value
    d1 = (np.log(data['close'] / data['close']) + (0.05 + (0.2 * 0.2) / 2) * days_to_expiration / 365) / (0.2 * np.sqrt(days_to_expiration / 365))
    d2 = d1 - 0.2 * np.sqrt(days_to_expiration / 365)
    theta_call = -(data['close'] * 0.2 * np.exp(-0.05 * days_to_expiration / 365) * (np.exp(-(d1 ** 2) / 2) / np.sqrt(2 * np.pi))) / \
                 (2 * np.sqrt(days_to_expiration / 365)) - 0.05 * 100 * np.exp(-0.05 * days_to_expiration / 365) * \
                 (np.exp(-(d2 ** 2) / 2) / np.sqrt(2 * np.pi))
    data['theta'] = theta_call

    # Normalize Theta
    data['normalized_theta'] = (data['theta'] - data['theta'].rolling(window=100).min()) / \
                               (data['theta'].rolling(window=100).max() - data['theta'].rolling(window=100).min())

    # Composite SOSI Calculation
    data['sosi_base'] = 0.1 * data['VWPCI'] + 0.2 * data['ROC'] + 0.3 * data['MVI']
    data['sosi'] = data['sosi_base'] + 0.4 * data['normalized_vold'] + 0.1 * data['normalized_theta']

    # Calculate slopes
    data['sosi_slope'] = data['sosi'] - data['sosi'].shift(1)
    data['vold_slope'] = data['normalized_vold'] - data['normalized_vold'].shift(1)

    # Define conditions
    data['condition1'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])
    data['condition2'] = (data['sosi'] > 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] > data['normalized_vold'])
    data['condition3'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['sosi'].shift(1) < data['sosi'].shift(2)) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['normalized_vold'].shift(1) < data['normalized_vold'].shift(2))
    data['condition4'] = (data['sosi_slope'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])

    # Combine conditions into the buy signal
    data['Buy Signal SOSI Final'] = (data['time_ist'].dt.time == pd.Timestamp('09:20:00').time()) & (data['condition1'] | data['condition2'] | data['condition3'] | data['condition4'])

    # Define BMM and SMM conditions
    data['BMM Condition'] = (data['time_ist'].dt.time == pd.Timestamp('09:16:00').time()) & (data['sosi'] > 0) & (data['normalized_vold'] > 0) & (data['sosi'] > data['normalized_vold'])
    data['SMM Condition'] = (data['time_ist'].dt.time == pd.Timestamp('09:16:00').time()) & (data['sosi'] < 0) & (data['normalized_vold'] < 0) & (data['sosi'] < data['normalized_vold'])

    # Check for BMM and SMM conditions 4 minutes before the buy signal
    data['Buy Signal with BMM'] = data['Buy Signal SOSI Final'] & data['BMM Condition'].shift(4)
    data['Buy Signal with SMM'] = data['Buy Signal SOSI Final'] & data['SMM Condition'].shift(4)

    # Define independent Buy Signals for BMM and SMM
    data['Buy Signal BMM'] = (data['BMM Condition']) & (data['Buy Signal SOSI Final'])
    data['Buy Signal SMM'] = (data['SMM Condition']) & (data['Buy Signal SOSI Final'])

    return data

# Function to calculate charges
def calculate_charges(entry_price, exit_price, quantity):
    brokerage = 40  # total brokerage for one complete buy and sell
    stt_ctt = 0.00125 * exit_price * quantity
    transaction_charges = 0.000495 * (entry_price + exit_price) * quantity
    gst = 0.18 * (brokerage + transaction_charges)
    sebi_charges = 10 / 10**7 * (entry_price + exit_price) * quantity
    stamp_charges = 0.00003 * entry_price * quantity
    total_charges = brokerage + stt_ctt + transaction_charges + gst + sebi_charges + stamp_charges
    return total_charges

# Function to simulate day trades with error margin
def simulate_day_trades(buy_signals, minute_data, symbol, profit_target=0.02, stop_loss=0.01, min_stop_loss=0.005, error_margin=0.03):
    results = []

    for index, buy_signal in buy_signals.iterrows():
        entry_price = buy_signal['close'] * (1 + error_margin)  # Adjust entry price with error margin
        entry_time = buy_signal['time'] + 60  # Add 1 minute to the buy signal time to get the entry time

        # Convert entry_time from epoch to datetime
        entry_datetime = pd.to_datetime(entry_time, unit='s')
        entry_datetime_ist = entry_datetime + timedelta(hours=5, minutes=30)  # Convert to IST
        
        # Check if the entry time is post 2:30 PM IST
        if entry_datetime_ist.time() >= datetime.strptime('14:30:00', '%H:%M:%S').time():
            continue  # Skip trades initiated after 2:30 PM IST

        profit_price = entry_price * (1 + profit_target)
        stop_price = entry_price * (1 - max(stop_loss, min_stop_loss))  # Ensure stop loss is at least min_stop_loss
        
        trade_result = {
            'signal_time': buy_signal['time'],
            'entry_time': entry_time,
            'entry_price': entry_price,
            'Target Profit': profit_target,
            'Stop Loss': stop_loss,
            'Profit Price': profit_price,
            'Stop Price': stop_price,
            'exit_time': None,
            'exit_price': None,
            'charges': None,
            'profit_before_charges': None,
            'profit': None,
            'exit_reason': None,
            'SOSI': buy_signal.get('SOSI'),
            'Normalized VOLD Ratio': buy_signal.get('normalized_vold'),
            'Normalized Theta': buy_signal.get('normalized_theta')
        }
        
        # Filter subsequent data for the same day only
        trade_date = pd.to_datetime(entry_time, unit='s').date()
        subsequent_data = minute_data[(minute_data['time'] > entry_time) & 
                                      (pd.to_datetime(minute_data['time'], unit='s').dt.date == trade_date)]
        
        for _, row in subsequent_data.iterrows():
            if row['high'] >= profit_price:
                trade_result['exit_time'] = row['time']
                trade_result['exit_price'] = profit_price
                trade_result['exit_reason'] = 'Target Hit'
                break
            if row['low'] <= stop_price:
                trade_result['exit_time'] = row['time']
                trade_result['exit_price'] = stop_price
                trade_result['exit_reason'] = 'Stop Loss Hit'
                break
        else:
            # If no target or stop loss hit, exit at the last price of the day
            trade_result['exit_reason'] = 'End of Day Exit'
            if not subsequent_data.empty:
                last_row = subsequent_data.iloc[-1]
                trade_result['exit_time'] = last_row['time']
                trade_result['exit_price'] = last_row['close']
        
        if trade_result['exit_price'] is not None:
            quantity = 25 if 'NIFTY' in symbol else 15 if 'BANKNIFTY' in symbol else 40 if 'FINNIFTY' in symbol else 10
            gross_profit = (trade_result['exit_price'] - trade_result['entry_price']) * quantity
            charges = calculate_charges(trade_result['entry_price'], trade_result['exit_price'], quantity)
            net_profit = gross_profit - charges
            trade_result['charges'] = charges
            trade_result['profit_before_charges'] = gross_profit
            trade_result['profit'] = net_profit

        results.append(trade_result)
    
    results_df = pd.DataFrame(results)

    if results_df.empty:
        return pd.DataFrame(columns=['signal_time', 'entry_time', 'entry_price', 'Target Profit', 'Stop Loss', 
                                     'Profit Price', 'Stop Price', 'exit_time', 'exit_price', 'charges', 
                                     'profit_before_charges', 'profit', 'exit_reason', 'SOSI', 
                                     'Normalized VOLD Ratio', 'Normalized Theta'])
    
    return results_df.dropna(subset=['entry_price'])

# Function to analyze profit and stop loss percentages
def analyze_profit_and_stop_loss(buy_signals, minute_data, profit_percentages, stop_loss_percentages, min_stop_loss=0.005, error_margin=0.01):
    analysis_results = []
    finalresults = []
    for profit_target in profit_percentages:
        for stop_loss in stop_loss_percentages:
            trade_results = simulate_day_trades(buy_signals, minute_data, folder_name, profit_target, stop_loss, min_stop_loss, error_margin)
            total_profit = trade_results['profit'].sum()
            charges = trade_results['charges'].sum()
            profit_before_charges = trade_results['profit_before_charges'].sum()
            analysis_results.append((profit_target, stop_loss, charges, profit_before_charges, total_profit))
            finalresults.append(trade_results)
    # Combine all trade results into a single DataFrame
    combined_trade_results = pd.concat(finalresults, ignore_index=True)
 
    return pd.DataFrame(analysis_results, columns=['Profit Target', 'Stop Loss', 'Charges', 'Profit Before Charges', 'Total Profit']), combined_trade_results

# Function to summarize trade results
def summarize_trade_results(trade_results):
    total_trades = len(trade_results)
    target_hit = len(trade_results[trade_results['exit_reason'] == 'Target Hit'])
    stop_loss_hit = len(trade_results[trade_results['exit_reason'] == 'Stop Loss Hit'])
    end_of_day_exit = len(trade_results[trade_results['exit_reason'] == 'End of Day Exit'])
    max_drawdown = trade_results['profit'].min()
    summary = {
        'Total Trades': total_trades,
        'Target Hit': target_hit,
        'Stop Loss Hit': stop_loss_hit,
        'End of Day Exit': end_of_day_exit,
        'Max Drawdown': max_drawdown
    }
    return summary

# Define profit percentages and stop loss percentages to analyze
profit_percentages = [i / 100 for i in range(1, 2)]
stop_loss_percentages = [i / 100 for i in range(1, 2)]

# Directories containing the data
directories = ['June 2024/NIFTY', 'June 2024/BANKNIFTY', 'June 2024/FINNIFTY']  # Change the directories as needed

# Function to check if the date is within the week of expiration
def is_within_expiry_week(expiry_date, timestamp, folder_name, days_before_expiry=5):
    # Assuming the date is the 7th to 12th characters in the string
    if folder_name == 'NIFTY':
        date_part = expiry_date[9:15]
    if folder_name == 'BANKNIFTY':
        date_part = expiry_date[13:19]
    if folder_name == 'FINNIFTY':
        date_part = expiry_date[12:18]
    if folder_name == 'SENSEX':
        date_part = expiry_date[7:13]
    
    expiry_datetime = pd.to_datetime(date_part, format='%y%m%d')
    signal_datetime = pd.to_datetime(timestamp, unit='s')
    return (expiry_datetime - signal_datetime).days <= days_before_expiry

# Process each directory
for directory in directories:
    pnl_results = []
    trade_results_combined = []
    all_combined_results = []
    folder_name = os.path.basename(directory)
    for subdir, _, files in os.walk(directory):
        if subdir == directory:
            continue  # Skip the top-level directory itself
        for filename in files:
            if ', 1.csv' in filename:  # Change to ', 1.csv' for 1-minute data
                minute_1_path = os.path.join(subdir, filename)
                
                if os.path.exists(minute_1_path):
                    print(f"Processing {filename} in {folder_name}...")
                    
                    # Extract expiry date from filename
                    expiry_date = filename.split(' ')[0].split(',')[0]
                    
                    # Load the CSV file
                    minute_data_1 = pd.read_csv(minute_1_path)
                    
                    # Filter buy signals
                    buy_signals = filter_signals(minute_data_1)

                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found for {filename}. Skipping...")
                        continue
                    # Filter signals to only include those within the expiry week
                    buy_signals = buy_signals[buy_signals['time'].apply(lambda x: is_within_expiry_week(expiry_date, x, folder_name))]
                    
                    # Skip if no buy signals within expiry week
                    if buy_signals.empty:
                        print(f"No buy signals found within expiry week for {filename}. Skipping...")
                        continue
                    
                    # Perform the analysis
                    analysis_results, trade_results = analyze_profit_and_stop_loss(buy_signals, minute_data_1, profit_percentages, stop_loss_percentages)
                    
                    # Merge buy signals with trade results
                    combined_results = pd.merge(buy_signals, trade_results, left_on='time', right_on='signal_time', how='inner')
                    
                    # Merge the 1-minute chart data with combined results
                    combined_results = pd.merge(combined_results, minute_data_1, left_on='time', right_on='time', suffixes=('_buy', '_original'))
                   
                    all_combined_results.append(combined_results)
                    
                    # Append to combined results
                    pnl_results.append(analysis_results)
                    trade_results_combined.append(trade_results)
    
    # Combine all results for the folder
    if not pnl_results:
        print(f"No data found for {folder_name}. Skipping...")
        continue    
    combined_pnl_results = pd.concat(pnl_results, ignore_index=True)
    # Aggregate total profits for the same combinations
    combined_pnl_results = combined_pnl_results.groupby(['Profit Target', 'Stop Loss'], as_index=False)['Total Profit'].sum()
    combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
    combined_all_results = pd.concat(all_combined_results, ignore_index=True)
    
    # Save the results to CSV files
    output_dir = f'Outputs/DayTrade/SOSI/1min/{folder_name}'
    os.makedirs(output_dir, exist_ok=True)
    
    combined_pnl_results.to_csv(f'{output_dir}/{folder_name}_pnl_analysis.csv', index=False)
    combined_trade_results.to_csv(f'{output_dir}/{folder_name}_trade_results.csv', index=False)
    combined_all_results.to_csv(f'{output_dir}/{folder_name}_all_combined_results.csv', index=False)
    
    # Find the best combination of profit target and stop loss
    if not combined_pnl_results.empty:
        best_combination = combined_pnl_results.loc[combined_pnl_results['Total Profit'].idxmax()]
        
        # Save the best combination
        best_combination_df = pd.DataFrame([best_combination])
        best_combination_df.to_csv(f'{output_dir}/{folder_name}_best_combination.csv', index=False)
        
        # Save the top 40 combinations
        top_40_combinations = combined_pnl_results.sort_values(by='Total Profit', ascending=False).head(40)
        top_40_combinations.to_csv(f'{output_dir}/{folder_name}_top_40_combinations.csv', index=False)
        
        # Filter the best trade results from the combined trade results
        best_trade_results = combined_trade_results[(combined_trade_results['Target Profit'] == best_combination['Profit Target']) & 
                                                    (combined_trade_results['Stop Loss'] == best_combination['Stop Loss'])]
        
        # Summarize the trade results for the best combination
        trade_summary = summarize_trade_results(best_trade_results)
        
        # Save the trade summary
        trade_summary_df = pd.DataFrame([trade_summary])
        trade_summary_df.to_csv(f'{output_dir}/{folder_name}_trade_summary.csv', index=False)
        
        # Plot the pie chart for trade summary
        labels = ['Target Hit', 'Stop Loss Hit', 'End of Day Exit']
        sizes = [trade_summary['Target Hit'], trade_summary['Stop Loss Hit'], trade_summary['End of Day Exit']]
        colors = ['lightgreen', 'lightcoral', 'lightskyblue']
        plt.figure(figsize=(8, 8))
        plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
        plt.title(f'Trade Summary for Best PNL Combination\n{folder_name}')
        plt.axis('equal')
        plt.show()
        plt.savefig(f'{output_dir}/{folder_name}_trade_summary_pie_chart.png')
        plt.close()
        
        # Plot the bar chart for total trades
        plt.figure(figsize=(12, 8))
        plt.barh(['Total Trades'], [trade_summary['Total Trades']], color='skyblue')
        plt.xlabel('Count')
        plt.ylabel('Total Trades')
        plt.title(f'Total Trades for Best PNL Combination\n{folder_name}')
        plt.tight_layout()
        plt.show()
        plt.savefig(f'{output_dir}/{folder_name}_total_trades_bar_chart.png')
        plt.close()

        # Plot the bar chart for max drawdown
        plt.figure(figsize=(12, 8))
        plt.barh(['Max Drawdown'], [trade_summary['Max Drawdown']], color='red')
        plt.xlabel('Max Drawdown')
        plt.ylabel('Max Drawdown Value')
        plt.title(f'Max Drawdown for Best PNL Combination\n{folder_name}')
        plt.tight_layout()
        plt.show()
        plt.savefig(f'{output_dir}/{folder_name}_max_drawdown_bar_chart.png')
        plt.close()

        # Plot the heatmap for better visualization
        pivot_table = combined_pnl_results.pivot(index="Stop Loss", columns="Profit Target", values="Total Profit")
        plt.figure(figsize=(10, 8))
        sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={'label': 'Total Profit'})
        plt.title(f"Total Profit for Different Profit Targets and Stop Loss Percentages\n{folder_name}")
        plt.xlabel("Profit Target")
        plt.ylabel("Stop Loss")
        plt.show()
        plt.savefig(f'{output_dir}/{folder_name}_heatmap.png')
        plt.close()

        # Plot the bar chart for the top 40 combinations
        plt.figure(figsize=(12, 8))
        plt.barh(top_40_combinations['Profit Target'].astype(str) + " / " + top_40_combinations['Stop Loss'].astype(str),
                 top_40_combinations['Total Profit'], color='skyblue')
        plt.xlabel('Total Profit')
        plt.ylabel('Profit Target / Stop Loss')
        plt.title(f'Top 40 Profit Target and Stop Loss Combinations\n{folder_name}')
        plt.gca().invert_yaxis()  # To display the highest
        plt.tight_layout()
        plt.show()
        plt.savefig(f'{output_dir}/{folder_name}_top_40_combinations.png')
        plt.close()

# Generate reports for each type of buy signal
buy_signal_types = {
    "Buy Signal SOSI Final": "Buy Signal Final SOSI",
    "Buy Signal with BMM": "Buy Signal with BMM",
    "Buy Signal with SMM": "Buy Signal with SMM",
    "BMM Condition": "BMM Condition",
    "SMM Condition": "SMM Condition"
}

for signal_column, signal_name in buy_signal_types.items():
    for directory in directories:
        pnl_results = []
        trade_results_combined = []
        all_combined_results = []
        folder_name = os.path.basename(directory)
        for subdir, _, files in os.walk(directory):
            if subdir == directory:
                continue  # Skip the top-level directory itself
            for filename in files:
                if ', 1.csv' in filename:  # Change to ', 1.csv' for 1-minute data
                    minute_1_path = os.path.join(subdir, filename)
                    
                    if os.path.exists(minute_1_path):
                        print(f"Processing {filename} in {folder_name} for {signal_name}...")
                        
                        # Extract expiry date from filename
                        expiry_date = filename.split(' ')[0].split(',')[0]
                        
                        # Load the CSV file
                        minute_data_1 = pd.read_csv(minute_1_path)
                        
                        # Filter buy signals
                        if signal_column not in minute_data_1.columns:
                            minute_data_1 = calculate_indicators(minute_data_1)
                        
                        if signal_column not in minute_data_1.columns:
                            print(f"Error: {signal_column} column not found in the data.")
                            continue
                        
                        buy_signals = minute_data_1[minute_data_1[signal_column] == True]

                        # Skip if no buy signals
                        if buy_signals.empty:
                            print(f"No {signal_name} found for {filename}. Skipping...")
                            continue
                        # Filter signals to only include those within the expiry week
                        buy_signals = buy_signals[buy_signals['time'].apply(lambda x: is_within_expiry_week(expiry_date, x, folder_name))]
                        
                        # Skip if no buy signals within expiry week
                        if buy_signals.empty:
                            print(f"No {signal_name} found within expiry week for {filename}. Skipping...")
                            continue
                        
                        # Perform the analysis
                        analysis_results, trade_results = analyze_profit_and_stop_loss(buy_signals, minute_data_1, profit_percentages, stop_loss_percentages)
                        
                        # Merge buy signals with trade results
                        combined_results = pd.merge(buy_signals, trade_results, left_on='time', right_on='signal_time', how='inner')
                        
                        # Merge the 1-minute chart data with combined results
                        combined_results = pd.merge(combined_results, minute_data_1, left_on='time', right_on='time', suffixes=('_buy', '_original'))
                       
                        all_combined_results.append(combined_results)
                        
                        # Append to combined results
                        pnl_results.append(analysis_results)
                        trade_results_combined.append(trade_results)
        
        # Combine all results for the folder
        if not pnl_results:
            print(f"No data found for {folder_name}. Skipping...")
            continue    
        combined_pnl_results = pd.concat(pnl_results, ignore_index=True)
        # Aggregate total profits for the same combinations
        combined_pnl_results = combined_pnl_results.groupby(['Profit Target', 'Stop Loss'], as_index=False)['Total Profit'].sum()
        combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
        combined_all_results = pd.concat(all_combined_results, ignore_index=True)
        
        # Save the results to CSV files
        signal_output_dir = f'Outputs/DayTrade/SOSI/1min/{folder_name}/{signal_name}'
        os.makedirs(signal_output_dir, exist_ok=True)
        
        combined_pnl_results.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_pnl_analysis.csv', index=False)
        combined_trade_results.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_trade_results.csv', index=False)
        combined_all_results.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_all_combined_results.csv', index=False)
        
        # Find the best combination of profit target and stop loss
        if not combined_pnl_results.empty:
            best_combination = combined_pnl_results.loc[combined_pnl_results['Total Profit'].idxmax()]
            
            # Save the best combination
            best_combination_df = pd.DataFrame([best_combination])
            best_combination_df.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_best_combination.csv', index=False)
            
            # Save the top             40 combinations
            top_40_combinations = combined_pnl_results.sort_values(by='Total Profit', ascending=False).head(40)
            top_40_combinations.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_top_40_combinations.csv', index=False)
            
            # Filter the best trade results from the combined trade results
            best_trade_results = combined_trade_results[(combined_trade_results['Target Profit'] == best_combination['Profit Target']) & 
                                                        (combined_trade_results['Stop Loss'] == best_combination['Stop Loss'])]
            
            # Summarize the trade results for the best combination
            trade_summary = summarize_trade_results(best_trade_results)
            
            # Save the trade summary
            trade_summary_df = pd.DataFrame([trade_summary])
            trade_summary_df.to_csv(f'{signal_output_dir}/{folder_name}_{signal_name}_trade_summary.csv', index=False)
            
            # Plot the pie chart for trade summary
            labels = ['Target Hit', 'Stop Loss Hit', 'End of Day Exit']
            sizes = [trade_summary['Target Hit'], trade_summary['Stop Loss Hit'], trade_summary['End of Day Exit']]
            colors = ['lightgreen', 'lightcoral', 'lightskyblue']
            plt.figure(figsize=(8, 8))
            plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
            plt.title(f'Trade Summary for Best PNL Combination\n{folder_name} ({signal_name})')
            plt.axis('equal')
            plt.show()
            plt.savefig(f'{signal_output_dir}/{folder_name}_{signal_name}_trade_summary_pie_chart.png')
            plt.close()
            
            # Plot the bar chart for total trades
            plt.figure(figsize=(12, 8))
            plt.barh(['Total Trades'], [trade_summary['Total Trades']], color='skyblue')
            plt.xlabel('Count')
            plt.ylabel('Total Trades')
            plt.title(f'Total Trades for Best PNL Combination\n{folder_name} ({signal_name})')
            plt.tight_layout()
            plt.show()
            plt.savefig(f'{signal_output_dir}/{folder_name}_{signal_name}_total_trades_bar_chart.png')
            plt.close()

            # Plot the bar chart for max drawdown
            plt.figure(figsize=(12, 8))
            plt.barh(['Max Drawdown'], [trade_summary['Max Drawdown']], color='red')
            plt.xlabel('Max Drawdown')
            plt.ylabel('Max Drawdown Value')
            plt.title(f'Max Drawdown for Best PNL Combination\n{folder_name} ({signal_name})')
            plt.tight_layout()
            plt.show()
            plt.savefig(f'{signal_output_dir}/{folder_name}_{signal_name}_max_drawdown_bar_chart.png')
            plt.close()

            # Plot the heatmap for better visualization
            pivot_table = combined_pnl_results.pivot(index="Stop Loss", columns="Profit Target", values="Total Profit")
            plt.figure(figsize=(10, 8))
            sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={'label': 'Total Profit'})
            plt.title(f"Total Profit for Different Profit Targets and Stop Loss Percentages\n{folder_name} ({signal_name})")
            plt.xlabel("Profit Target")
            plt.ylabel("Stop Loss")
            plt.show()
            plt.savefig(f'{signal_output_dir}/{folder_name}_{signal_name}_heatmap.png')
            plt.close()

            # Plot the bar chart for the top 40 combinations
            plt.figure(figsize=(12, 8))
            plt.barh(top_40_combinations['Profit Target'].astype(str) + " / " + top_40_combinations['Stop Loss'].astype(str),
                     top_40_combinations['Total Profit'], color='skyblue')
            plt.xlabel('Total Profit')
            plt.ylabel('Profit Target / Stop Loss')
            plt.title(f'Top 40 Profit Target and Stop Loss Combinations\n{folder_name} ({signal_name})')
            plt.gca().invert_yaxis()  # To display the highest
            plt.tight_layout()
            plt.show()
            plt.savefig(f'{signal_output_dir}/{folder_name}_{signal_name}_top_40_combinations.png')
            plt.close()

print("Analysis complete.")
# Out:
# Processing NSE_NIFTY240620C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23300, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23450, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23450, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23750, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23750, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23900, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24050, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C24050, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24250, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240711C24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24250, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24350, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24500, 1.csv in NIFTY...
# C:\temp\ipykernel_16592\1628767216.py:316: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:317: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_BANKNIFTY240619C50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52100, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_BANKNIFTY240703C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710P52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53200, 1.csv in BANKNIFTY...
# C:\temp\ipykernel_16592\1628767216.py:316: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:317: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_FINNIFTY240625C22500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23200, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C24000, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_FINNIFTY240709P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240709P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P24000, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23500, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23600, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23700, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C24000, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23550, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23700, 1.csv in FINNIFTY...
# C:\temp\ipykernel_16592\1628767216.py:316: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:317: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_NIFTY240620C23400, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23500, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23550, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23600, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23400, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23500, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23550, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620P23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23600, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240620P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23300, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23300, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23400, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23450, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23450, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23500, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23550, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23600, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23700, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23750, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23750, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23800, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23400, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23500, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23600, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23700, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627P23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23800, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240627P23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23700, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240704C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23800, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found within expiry week for NSE_NIFTY240704C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23900, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found within expiry week for NSE_NIFTY240704C23900, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24000, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704C24050, 1.csv in NIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_NIFTY240704C24050, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24100, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704C24150, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704C24200, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704C24250, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704C24300, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P23800, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P23900, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P24000, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P24100, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P24150, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P24200, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240704P24300, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24200, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24250, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24300, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24350, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24400, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711C24500, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711P24200, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711P24300, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711P24400, 1.csv in NIFTY for Buy Signal Final SOSI...
# Processing NSE_NIFTY240711P24500, 1.csv in NIFTY for Buy Signal Final SOSI...
# C:\temp\ipykernel_16592\1628767216.py:483: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:484: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_BANKNIFTY240619C50400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619C50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619C50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619C50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619P50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619P50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240619P50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51300, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51700, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51800, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51900, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C51900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52000, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C52000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52100, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C52100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51300, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626P51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Error: 'volume' column not found in the data.
# Error: Buy Signal SOSI Final column not found in the data.
# Processing NSE_BANKNIFTY240626P51500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626P51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_BANKNIFTY240626P51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52200, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52300, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found within expiry week for NSE_BANKNIFTY240703C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52700, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52800, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C52900, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703C53000, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52200, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52300, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52700, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52800, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P52900, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240703P53000, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52300, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52700, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52800, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C52900, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C53000, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C53100, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C53200, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710C53500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52400, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52500, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52600, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52700, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52800, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P52900, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P53000, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P53100, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# Processing NSE_BANKNIFTY240710P53200, 1.csv in BANKNIFTY for Buy Signal Final SOSI...
# C:\temp\ipykernel_16592\1628767216.py:483: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:484: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_FINNIFTY240625C22500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625C22500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22800, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625C22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22900, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625C22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23000, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625C23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23100, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Error: 'volume' column not found in the data.
# Error: Buy Signal SOSI Final column not found in the data.
# Processing NSE_FINNIFTY240625P22800, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625P22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22900, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625P22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23000, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625P23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23100, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240625P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23100, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702C23200, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702C23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23450, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702C23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702C23550, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702C23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702C23650, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702C23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23100, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240702P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23300, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23400, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23450, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23550, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23650, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240702P23800, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23400, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23800, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C23900, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709C24000, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P23400, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found within expiry week for NSE_FINNIFTY240709P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23450, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240709P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P23800, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P23900, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240709P24000, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240709P24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240716C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240716C23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240716C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C24000, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# No Buy Signal Final SOSI found for NSE_FINNIFTY240716C24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23500, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240716P23550, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240716P23600, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# Processing NSE_FINNIFTY240716P23700, 1.csv in FINNIFTY for Buy Signal Final SOSI...
# C:\temp\ipykernel_16592\1628767216.py:483: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_trade_results = pd.concat(trade_results_combined, ignore_index=True)
# C:\temp\ipykernel_16592\1628767216.py:484: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_all_results = pd.concat(all_combined_results, ignore_index=True)
# Processing NSE_NIFTY240620C23400, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23500, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23550, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23600, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23400, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23500, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23550, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620P23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23600, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240620P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23300, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23300, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23400, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23450, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23450, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23500, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23550, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23600, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23700, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23750, 1.csv in NIFTY for Buy Signal with BMM...
# No Buy Signal with BMM found for NSE_NIFTY240627C23750, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23800, 1.csv in NIFTY for Buy Signal with BMM...
# ...
# Processing NSE_BANKNIFTY240626C51300, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51400, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51700, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51800, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51900, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C51900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52000, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C52000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52100, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C52100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51300, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626P51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51400, 1.csv in BANKNIFTY for SMM Condition...
# Error: 'volume' column not found in the data.
# Error: SMM Condition column not found in the data.
# Processing NSE_BANKNIFTY240626P51500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626P51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240626P51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52200, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52200, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52300, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52400, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52700, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52800, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52900, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C52900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C53000, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703C53000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52200, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52200, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52300, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52400, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52700, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52800, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P52900, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P52900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703P53000, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240703P53000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52300, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52400, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52700, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52800, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C52900, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C52900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C53000, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C53000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C53100, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C53100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C53200, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C53200, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710C53500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710C53500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52400, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52500, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52600, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52700, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52800, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P52900, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P52900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P53000, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P53000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P53100, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P53100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240710P53200, 1.csv in BANKNIFTY for SMM Condition...
# No SMM Condition found for NSE_BANKNIFTY240710P53200, 1.csv. Skipping...
# No data found for BANKNIFTY. Skipping...
# Processing NSE_FINNIFTY240625C22500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625C22500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22800, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625C22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22900, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625C22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23000, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625C23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23100, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23500, 1.csv in FINNIFTY for SMM Condition...
# Error: 'volume' column not found in the data.
# Error: SMM Condition column not found in the data.
# Processing NSE_FINNIFTY240625P22800, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625P22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22900, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625P22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23000, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625P23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23100, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240625P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23100, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23200, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23450, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23550, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23550, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23650, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23650, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23100, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23300, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23400, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23450, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23550, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23550, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23650, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23650, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23800, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240702P23800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23400, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23800, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C23900, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C23900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709C24000, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709C24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23400, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23450, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23800, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23900, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P23900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P24000, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240709P24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716C23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C24000, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716C24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23500, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716P23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23550, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716P23550, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23600, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716P23600, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716P23700, 1.csv in FINNIFTY for SMM Condition...
# No SMM Condition found for NSE_FINNIFTY240716P23700, 1.csv. Skipping...
# No data found for FINNIFTY. Skipping...
# Analysis complete.
