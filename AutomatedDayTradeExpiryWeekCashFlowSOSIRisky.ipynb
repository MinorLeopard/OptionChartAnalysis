# %% [markdown]
# Checking Cash Flow for Hardy based signalling and account growth over time, for better planning and account management. for SOSI Risky Stop Loss

# %% [markdown]
# 1. Read the best PNL values
# Read the best stop loss and target profit values for NIFTY, BANKNIFTY, and FINNIFTY from a file.
# 2. Filter buy signals
# From the 15-minute chart data, filter out buy signals that are original buy signals and not short signals.
# 3. Calculate charges
# Define a function to calculate the charges for a trade including brokerage, STT/CTT, transaction charges, GST, SEBI charges, and stamp charges.
# 4. Simulate all trades
# For each buy signal, determine the entry price and calculate the profit price and stop price.
# Determine the exit time and price based on subsequent data for the same day.
# Calculate the profit or loss for the trade and append it to the results.
# 5. Simulate live trading account
# Initialize the account with the initial balance.
# Iterate through each second from the earliest entry time to the latest exit time.
# For each second, handle exiting trades first by adding their profit or loss back to the account balance.
# Then, handle entering trades by checking if the account balance is sufficient to cover the trade cost. If not, mark the trade as missed.
# Keep track of the daily balance, executed trades, and missed trades.
# 6. Process each directory
# For each directory (NIFTY, BANKNIFTY, FINNIFTY), load the 15-minute chart data, filter buy signals, and simulate all trades using the best PNL values.
# 7. Combine all trades
# Combine all trades from different indexes into a single DataFrame and sort by entry time.
# 8. Simulate live trading account
# Use the combined trades to simulate the live trading account and get the daily balance, missed trades, and executed trades.
# 9. Save results and generate visualizations
# Save the combined trades, daily balance, missed trades, and executed trades to CSV files.
# Generate visualizations for the daily balance, worst trade, best trade, max drawdown, highest balance, count of missed trades, histogram of trade profits, pie chart of trade outcomes, and summary statistics.
# This approach ensures that the simulation takes into account the initial capital and handles trades in a realistic manner, updating the account balance as trades are

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
import numpy as np

# Function to read best PNL combinations from a file
def read_best_pnl(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        best_pnl_values = {
            'NIFTY': {'stop_loss': float(lines[14].strip()), 'target': float(lines[15].strip())},
            'BANKNIFTY': {'stop_loss': float(lines[16].strip()), 'target': float(lines[17].strip())},
            'FINNIFTY': {'stop_loss': float(lines[18].strip()), 'target': float(lines[19].strip())}
        }
    return best_pnl_values


# Function to calculate indicators and buy signals
def calculate_indicators(data):
   
    # Calculate VWPCI
    if 'volume' in data.columns:
        volume = data['volume']
    elif 'Volume' in data.columns:
        volume = data['Volume']
    data['priceChangeRatio'] = (data['close'] - data['open']) / (data['high'] - data['low'])
    data['VWPCI'] = data['priceChangeRatio'] * volume


    # Convert Unix timestamp (UTC) to datetime
    data['time_utc'] = pd.to_datetime(data['time'], unit='s', utc=True)

    # Convert UTC to IST
    data['time_ist'] = data['time_utc'] + timedelta(hours=5, minutes=30)

    # Calculate ROC
    roc_periods = 14
    data['ROC'] = data['close'].pct_change(periods=roc_periods)

    # Calculate MVI
    data['MVI'] = volume * ((data['close'] - data['open']) / data['close'])

    # Calculate VOLD
    data['up_volume'] = np.where(data['close'] > data['close'].shift(1), volume, 0)
    data['down_volume'] = np.where(data['close'] <= data['close'].shift(1), volume, 0)
    data['total_up_volume'] = data['up_volume'].cumsum()
    data['total_down_volume'] = data['down_volume'].cumsum()
    data['VOLD_ratio'] = data['total_up_volume'] / data['total_down_volume']

    # Normalize VOLD
    data['normalized_vold'] = (data['VOLD_ratio'] - data['VOLD_ratio'].rolling(window=100).min()) / \
                              (data['VOLD_ratio'].rolling(window=100).max() - data['VOLD_ratio'].rolling(window=100).min())

    # Theta Calculation
    days_to_expiration = 30  # assuming a constant value
    d1 = (np.log(data['close'] / data['close']) + (0.05 + (0.2 * 0.2) / 2) * days_to_expiration / 365) / (0.2 * np.sqrt(days_to_expiration / 365))
    d2 = d1 - 0.2 * np.sqrt(days_to_expiration / 365)
    theta_call = -(data['close'] * 0.2 * np.exp(-0.05 * days_to_expiration / 365) * (np.exp(-(d1 ** 2) / 2) / np.sqrt(2 * np.pi))) / \
                 (2 * np.sqrt(days_to_expiration / 365)) - 0.05 * 100 * np.exp(-0.05 * days_to_expiration / 365) * \
                 (np.exp(-(d2 ** 2) / 2) / np.sqrt(2 * np.pi))
    data['theta'] = theta_call

    # Normalize Theta
    data['normalized_theta'] = (data['theta'] - data['theta'].rolling(window=100).min()) / \
                               (data['theta'].rolling(window=100).max() - data['theta'].rolling(window=100).min())

    # Composite SOSI Calculation
    data['sosi_base'] = 0.1 * data['VWPCI'] + 0.2 * data['ROC'] + 0.3 * data['MVI']
    data['sosi'] = data['sosi_base'] + 0.4 * data['normalized_vold'] + 0.1 * data['normalized_theta']

    # Calculate slopes
    data['sosi_slope'] = data['sosi'] - data['sosi'].shift(1)
    data['vold_slope'] = data['normalized_vold'] - data['normalized_vold'].shift(1)

    # Define conditions
    data['condition1'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])
    data['condition2'] = (data['sosi'] > 0) & (data['sosi_slope'] > 0) & (data['normalized_vold'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] > data['normalized_vold'])
    data['condition3'] = (data['sosi'] < 0) & (data['sosi_slope'] > 0) & (data['sosi'].shift(1) < data['sosi'].shift(2)) & (data['normalized_vold'] < 0) & (data['vold_slope'] > 0) & (data['normalized_vold'].shift(1) < data['normalized_vold'].shift(2))
    data['condition4'] = (data['sosi_slope'] > 0) & (data['vold_slope'] > 0) & (data['sosi'] < data['normalized_vold'])

    # Combine conditions into the buy signal
    data['Buy Signal SOSI Final'] = (data['time_ist'].dt.time == pd.Timestamp('09:20:00').time()) & (data['condition1'] | data['condition2'] | data['condition3'] | data['condition4'])

    return data



# Function to filter buy signals from the 1-minute chart data
def filter_signals(data):
    if 'Buy Signal SOSI Final' not in data.columns:
        print("Warning: 'Buy Signal SOSI Final' column not found in the data.")
        if 'volume' and 'Volume' not in data.columns:
            print("Error: 'volume' column not found in the data.")
            return pd.DataFrame()
        data=calculate_indicators(data)
        if 'Buy Signal SOSI Final' not in data.columns:
            print("Error: 'Buy Signal SOSI Final' column still not found in the data.")
            return pd.DataFrame()
        buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
        return buy_signals
        

    buy_signals = data[(data['Buy Signal SOSI Final'] == True)]
    return buy_signals



# Function to calculate charges
def calculate_charges(entry_price, exit_price, quantity):
    brokerage = 40  # total brokerage for one complete buy and sell
    stt_ctt = 0.00125 * exit_price * quantity
    transaction_charges = 0.000495 * (entry_price + exit_price) * quantity
    gst = 0.18 * (brokerage + transaction_charges)
    sebi_charges = 10 / 10**7 * (entry_price + exit_price) * quantity
    stamp_charges = 0.00003 * entry_price * quantity
    total_charges = brokerage + stt_ctt + transaction_charges + gst + sebi_charges + stamp_charges
    return total_charges

# Function to simulate day trades with error margin
def simulate_day_trades(buy_signals, minute_data, symbol, profit_target=0.02, stop_loss=0.01, min_stop_loss=0.005, error_margin=0.01):
    results = []

    for index, buy_signal in buy_signals.iterrows():
        entry_price = buy_signal['close'] #* (1 + error_margin)  # Adjust entry price with error margin
        entry_time = buy_signal['time'] + 900  # Add 15 minutes to the buy signal time to get the entry time
        profit_price = entry_price * (1 + profit_target)
        stop_price = entry_price * (1 - max(stop_loss, min_stop_loss))  # Ensure stop loss is at least min_stop_loss
        
        trade_result = {
            'symbol': symbol,
            'signal_time': buy_signal['time'],
            'entry_time': entry_time,
            'entry_price': entry_price,
            'Target Profit': profit_target,
            'Stop Loss': stop_loss,
            'Profit Price': profit_price,
            'Stop Price': stop_price,
            'exit_time': None,
            'exit_price': None,
            'charges': None,
            'profit_before_charges': None,
            'profit': None,
            'exit_reason': None,
            'missed': False
        }
        
        # Filter subsequent data for the same day only
        trade_date = pd.to_datetime(entry_time, unit='s').date()
        subsequent_data = minute_data[(minute_data['time'] > entry_time) & 
                                      (pd.to_datetime(minute_data['time'], unit='s').dt.date == trade_date)]
      
        error_margin = 0  # Default error margin for 1-minute data

        if subsequent_data.empty:
            # Use 15-minute chart data if 1-minute data is empty
            subsequent_data = minute_data_15[(minute_data_15['time'] > entry_time) & 
                                             (pd.to_datetime(minute_data_15['time'], unit='s').dt.date == trade_date)]
            error_margin = 960  # Adjust error margin for 15-minute data
            
        for _, row in subsequent_data.iterrows():
            if row['high'] >= profit_price:
                trade_result['exit_time'] = row['time'] + error_margin
                trade_result['exit_price'] = profit_price
                trade_result['exit_reason'] = 'Target Hit'
                break
            if row['low'] <= stop_price:
                trade_result['exit_time'] = row['time'] + error_margin
                trade_result['exit_price'] = stop_price
                trade_result['exit_reason'] = 'Stop Loss Hit'
                break
        else:
            # If no target or stop loss hit, exit at the last price of the day (3:25 PM)
            end_of_day_time = pd.to_datetime(trade_date) + pd.Timedelta(hours=15, minutes=25)
            eod_exit_data = minute_data[(pd.to_datetime(minute_data['time'], unit='s') <= end_of_day_time)]
            
            if eod_exit_data.empty:
                eod_exit_data = minute_data_15[(pd.to_datetime(minute_data_15['time'], unit='s') <= end_of_day_time)]
            
            if not eod_exit_data.empty:
                last_row = eod_exit_data.iloc[-1]
                trade_result['exit_time'] = last_row['time'] + error_margin
                trade_result['exit_price'] = last_row['close']
                trade_result['exit_reason'] = 'End of Day Exit'
        
        if trade_result['exit_price'] is not None:
            quantity = 25 if 'NIFTY' in symbol else 15 if 'BANKNIFTY' in symbol else 40 if 'FINNIFTY' in symbol else 10
            gross_profit = (trade_result['exit_price'] - trade_result['entry_price']) * quantity
            charges = calculate_charges(trade_result['entry_price'], trade_result['exit_price'], quantity)
            net_profit = gross_profit - charges
            trade_result['charges'] = charges
            trade_result['profit_before_charges'] = gross_profit
            trade_result['profit'] = net_profit

        results.append(trade_result)
    
    results_df = pd.DataFrame(results)

    return results_df.dropna(subset=['entry_price'])

# Function to simulate live trading account
def simulate_live_trading(all_trades, initial_balance):
    account_balance = initial_balance
    active_trades = []
    daily_balance = []
    missed_trades = []
    executed_trades = []

    current_time = pd.to_datetime(all_trades['entry_time'].min(), unit='s')
    end_time = pd.to_datetime(all_trades['exit_time'].max(), unit='s')
    print(f"Simulating live trading from {current_time} to {end_time}...")

    trading_end_time = current_time.replace(hour=11, minute=30, second=0, microsecond=0)

    while current_time <= end_time:


        # Skip non-trading hours
        if current_time.time() > trading_end_time.time():
            current_time = current_time + timedelta(days=1)
            current_time = current_time.replace(hour=3, minute=30, second=0, microsecond=0)
            continue

        # Handle exiting trades
        trades_to_remove = []
        for trade in active_trades:
            if trade['exit_time'] == current_time:
                print(f"Exiting trade at {trade['exit_price']} at {current_time}")
                trade_cost = trade['entry_price'] * (25 if 'NIFTY' in trade['symbol'] else 15 if 'BANKNIFTY' in trade['symbol'] else 40 if 'FINNIFTY' in trade['symbol'] else 10)
                account_balance += trade['profit'] + trade_cost
                print(f"Account Balance: {account_balance}")
                executed_trades.append(trade)
                trades_to_remove.append(trade.name)

        # Remove trades that have exited
        active_trades = [trade for trade in active_trades if trade.name not in trades_to_remove]

    

        # Handle entering trades
        current_trades = all_trades[all_trades['entry_time'] == current_time]
        if not current_trades.empty:
            print(f"Entering {len(current_trades)} trades at {current_time}")
        for index, trade in current_trades.iterrows():
            trade_cost = trade['entry_price'] * (25 if 'NIFTY' in trade['symbol'] else 15 if 'BANKNIFTY' in trade['symbol'] else 40 if 'FINNIFTY' in trade['symbol'] else 10)
            if account_balance >= trade_cost:
                account_balance -= trade_cost  # Deduct the trade cost from account balance
                active_trades.append(trade)
                print(f"Account Balance: {account_balance}")
                print(f"Entered trade at {trade['entry_price']} for {trade_cost} at {current_time}")
            else:
                trade['missed'] = True
                print(f"Missed trade at {trade['entry_price']} due to insufficient balance at {current_time}")
                missed_trades.append(trade)

        daily_balance.append({'date': current_time.date(), 'balance': account_balance})
        current_time += timedelta(seconds=1)

    daily_balance_df = pd.DataFrame(daily_balance).groupby('date').last().reset_index()
    missed_trades_df = pd.DataFrame(missed_trades)
    executed_trades_df = pd.DataFrame(executed_trades)
    print("Total trades executed:", len(executed_trades_df))
    print("Total missed trades:", len(missed_trades_df))
    print("Live trading simulation complete.")

    return daily_balance_df, missed_trades_df, executed_trades_df


# Function to check if the date is within the week of expiration
def is_within_expiry_week(expiry_date, timestamp, folder_name, days_before_expiry=5):
    # Assuming the date is the 7th to 12th characters in the string
    if folder_name == 'NIFTY':
        date_part = expiry_date[9:15]
    if folder_name == 'BANKNIFTY':
        date_part = expiry_date[13:19]
    if folder_name == 'FINNIFTY':
        date_part = expiry_date[12:18]
    if folder_name == 'SENSEX':
        date_part = expiry_date[7:13]
    
    expiry_datetime = pd.to_datetime(date_part, format='%y%m%d')
    signal_datetime = pd.to_datetime(timestamp, unit='s')
    return (expiry_datetime - signal_datetime).days <= days_before_expiry


# Read the best PNL values
best_pnl_file_path = 'bestpnlAnalysis.txt'
best_pnl_values = read_best_pnl(best_pnl_file_path)

# Directories containing the data
directories = ['June 2024/NIFTY', 'June 2024/BANKNIFTY', 'June 2024/FINNIFTY']  # Change the directories as needed

# Initial balance for the account
initial_balance = 100000  # Starting with 20000 INR

# Process each directory
all_trades = []

for directory in directories:
    folder_name = os.path.basename(directory)
    for subdir, _, files in os.walk(directory):
        if subdir == directory:
            continue  # Skip the top-level directory itself
        for filename in files:
            if ', 1.csv' in filename:
                minute_15_path = os.path.join(subdir, filename)
                
                if os.path.exists(minute_15_path):
                    print(f"Processing {filename} in {folder_name}...")
                    
                    # Extract expiry date from filename
                    # Extract expiry date from filename
                    expiry_date = filename.split(' ')[0].split(',')[0]
                    
                    # Load the CSV file
                    minute_data_15 = pd.read_csv(minute_15_path)
                    
                    # Filter buy signals
                    buy_signals = filter_signals(minute_data_15)

                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found for {filename}. Skipping...")
                        continue

                    # Filter signals to only include those within the expiry week
                    buy_signals = buy_signals[buy_signals['time'].apply(lambda x: is_within_expiry_week(expiry_date, x, folder_name))]
                    
                    # Skip if no buy signals
                    if buy_signals.empty:
                        print(f"No buy signals found within expiry week for {filename}. Skipping...")
                        continue
                    
                    # Get best PNL values for the current index
                    stop_loss = best_pnl_values[folder_name]['stop_loss']
                    profit_target = best_pnl_values[folder_name]['target']

                    # Simulate all trades
                    trades = simulate_day_trades(buy_signals, minute_data_15, folder_name, profit_target, stop_loss)
                    all_trades.append(trades)

# Combine all trades from different indexes
all_trades_df = pd.concat(all_trades, ignore_index=True)
all_trades_df['entry_time'] = pd.to_datetime(all_trades_df['entry_time'], unit='s')
all_trades_df['exit_time'] = pd.to_datetime(all_trades_df['exit_time'], unit='s')
all_trades_df = all_trades_df.sort_values(by='entry_time').reset_index(drop=True)

# Simulate live trading account
daily_balance_df, missed_trades_df, executed_trades_df = simulate_live_trading(all_trades_df, initial_balance)

# Create output directories
combined_output_dir = 'Outputs/DayTrade/Combined'
os.makedirs(combined_output_dir, exist_ok=True)

# Save combined trades and daily balance
all_trades_df.to_csv(f'{combined_output_dir}/all_trades.csv', index=False)
daily_balance_df.to_csv(f'{combined_output_dir}/daily_balance.csv', index=False)
missed_trades_df.to_csv(f'{combined_output_dir}/missed_trades.csv', index=False)
executed_trades_df.to_csv(f'{combined_output_dir}/executed_trades.csv', index=False)

# Plot the combined daily balance for all indexes
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['balance'], marker='o', linestyle='-', color='blue')
plt.xlabel('Date')
plt.ylabel('Account Balance')
plt.title('Daily Account Balance for Combined Trades Across All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/daily_balance.png')
plt.close()

# Calculate and plot the worst trade for all indexes
worst_trade_all = executed_trades_df.loc[executed_trades_df['profit'].idxmin()]
plt.figure(figsize=(12, 8))
plt.barh(['Worst Trade'], [worst_trade_all['profit']], color='red')
plt.xlabel('Profit')
plt.ylabel('Worst Trade')
plt.title('Worst Trade for All Indexes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/worst_trade_all.png')
plt.close()

# Calculate and plot the best trade for all indexes
best_trade_all = executed_trades_df.loc[executed_trades_df['profit'].idxmax()]
plt.figure(figsize=(12, 8))
plt.barh(['Best Trade'], [best_trade_all['profit']], color='green')
plt.xlabel('Profit')
plt.ylabel('Best Trade')
plt.title('Best Trade for All Indexes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/best_trade_all.png')
plt.close()

# Calculate and plot the max drawdown for all indexes
daily_balance_df['drawdown'] = daily_balance_df['balance'].cummax() - daily_balance_df['balance']
max_drawdown_all = daily_balance_df['drawdown'].max()
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['drawdown'], marker='o', linestyle='-', color='orange')
plt.xlabel('Date')
plt.ylabel('Drawdown')
plt.title('Max Drawdown for All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/max_drawdown_all.png')
plt.close()

# Calculate and plot the highest balance on each day for all indexes
daily_balance_df['highest_balance'] = daily_balance_df['balance'].cummax()
plt.figure(figsize=(12, 8))
plt.plot(daily_balance_df['date'], daily_balance_df['highest_balance'], marker='o', linestyle='-', color='purple')
plt.xlabel('Date')
plt.ylabel('Highest Balance')
plt.title('Highest Balance for All Indexes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/highest_balance_all.png')
plt.close()

# Calculate and plot missed trades due to insufficient capital
missed_trades_profitable = missed_trades_df[missed_trades_df['profit'] > 0]
missed_trades_loss = missed_trades_df[missed_trades_df['profit'] <= 0]
plt.figure(figsize=(12, 8))
plt.bar(['Profitable Missed Trades', 'Loss Making Missed Trades'], [len(missed_trades_profitable), len(missed_trades_loss)], color=['lightgreen', 'lightcoral'])
plt.xlabel('Type of Missed Trades')
plt.ylabel('Count')
plt.title('Count of Missed Trades Due to Insufficient Capital')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/missed_trades_count.png')
plt.close()

# Plot a histogram of trade profits
plt.figure(figsize=(12, 8))
plt.hist(executed_trades_df['profit'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.title('Histogram of Trade Profits')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/trade_profits_histogram.png')
plt.close()

# Pie chart of trade outcomes
outcomes = executed_trades_df['exit_reason'].value_counts()
plt.figure(figsize=(12, 8))
plt.pie(outcomes, labels=outcomes.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue', 'lightgreen'])
plt.title('Trade Outcomes')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/trade_outcomes_pie_chart.png')
plt.close()

# Summary statistics
summary_stats = {
    'Total Trades': len(executed_trades_df),
    'Total Missed Trades': len(missed_trades_df),
    'Total Profit': executed_trades_df['profit'].sum(),
    'Max Drawdown': max_drawdown_all,
    'Best Trade': best_trade_all['profit'],
    'Worst Trade': worst_trade_all['profit']
}
summary_stats_df = pd.DataFrame([summary_stats])
summary_stats_df.to_csv(f'{combined_output_dir}/summary_statistics.csv', index=False)

# Visualize summary statistics
plt.figure(figsize=(22, 18))
plt.barh(list(summary_stats.keys()), list(summary_stats.values()), color='skyblue')
plt.xlabel('Value')
plt.ylabel('Statistic')
plt.title('Summary Statistics')
plt.tight_layout()
plt.show()
plt.savefig(f'{combined_output_dir}/summary_statistics.png')
plt.close()

print("Final summary statistics:")
print(summary_stats_df)
print("Final Balance:", daily_balance_df['balance'].iloc[-1])
print("Max Drawdown:", max_drawdown_all)
print("Best Trade:", best_trade_all['profit'])
print("Worst Trade:", worst_trade_all['profit'])
print("Total Trades:", len(executed_trades_df))
print("Total Missed Trades:", len(missed_trades_df))
print("Total Profit:", executed_trades_df['profit'].sum())
print("Total Profitable Trades:", len(executed_trades_df[executed_trades_df['profit'] > 0]))


print("Analysis and visualization complete.")
# Out:
# Processing NSE_NIFTY240620C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23550, 1.csv. Skipping...
# Processing NSE_NIFTY240620P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240620P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23300, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23450, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23450, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23550, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23550, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23750, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23750, 1.csv. Skipping...
# Processing NSE_NIFTY240627C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23400, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23400, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23500, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23500, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23600, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23600, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23700, 1.csv. Skipping...
# Processing NSE_NIFTY240627P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240627P23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23700, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C23700, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23800, 1.csv. Skipping...
# Processing NSE_NIFTY240704C23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_NIFTY240704C23900, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24050, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_NIFTY240704C24050, 1.csv. Skipping...
# Processing NSE_NIFTY240704C24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24250, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704C24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23800, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P23900, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24000, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24100, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24150, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24200, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240704P24300, 1.csv in NIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_NIFTY240711C24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24250, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24350, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711C24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240711P24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24200, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24300, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24400, 1.csv in NIFTY...
# Processing NSE_NIFTY240718C24500, 1.csv in NIFTY...
# Processing NSE_NIFTY240718P24200, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24200, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24300, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24300, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24400, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24400, 1.csv. Skipping...
# Processing NSE_NIFTY240718P24500, 1.csv in NIFTY...
# No buy signals found within expiry week for NSE_NIFTY240718P24500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619C50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619C50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240619P50600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240619P50600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51700, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51800, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C51900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C51900, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52000, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52100, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52100, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51300, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51400, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51500, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240626P51600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_BANKNIFTY240626P51600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_BANKNIFTY240703C52600, 1.csv. Skipping...
# Processing NSE_BANKNIFTY240703C52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52200, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52300, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52400, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52600, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52700, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52800, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P52900, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240703P53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53000, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710C53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710C53500, 1.csv in BANKNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_BANKNIFTY240710P52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52600, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52700, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52800, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P52900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53100, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240710P53200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C51900, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716C52500, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52000, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52200, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52300, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52400, 1.csv in BANKNIFTY...
# Processing NSE_BANKNIFTY240716P52500, 1.csv in BANKNIFTY...
# Processing NSE_FINNIFTY240625C22500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Error: 'volume' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625C23500, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22800, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P22900, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P22900, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23000, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240625P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240625P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23200, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23200, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23300, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702C23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702C23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702C23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23100, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240702P23100, 1.csv. Skipping...
# Processing NSE_FINNIFTY240702P23300, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23500, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23550, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23600, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23650, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23700, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240702P23800, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# Processing NSE_FINNIFTY240709C23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709C24000, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23400, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found within expiry week for NSE_FINNIFTY240709P23400, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23450, 1.csv in FINNIFTY...
# Warning: 'Buy Signal SOSI Final' column not found in the data.
# No buy signals found for NSE_FINNIFTY240709P23450, 1.csv. Skipping...
# Processing NSE_FINNIFTY240709P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23700, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23800, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P23900, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240709P24000, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240709P24000, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C23400, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716C23700, 1.csv in FINNIFTY...
# No buy signals found for NSE_FINNIFTY240716C23700, 1.csv. Skipping...
# Processing NSE_FINNIFTY240716C24000, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23400, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23500, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23550, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23600, 1.csv in FINNIFTY...
# Processing NSE_FINNIFTY240716P23700, 1.csv in FINNIFTY...
# Simulating live trading from 2024-06-27 04:05:00 to 2024-07-12 05:30:00...
# Entering 12 trades at 2024-06-27 04:05:00
# Account Balance: 81800.0
# Entered trade at 728.0 for 18200.0 at 2024-06-27 04:05:00
# Account Balance: 65188.75
# Entered trade at 664.45 for 16611.25 at 2024-06-27 04:05:00
# Account Balance: 59937.5
# Entered trade at 210.05 for 5251.25 at 2024-06-27 04:05:00
# Account Balance: 55391.25
# Entered trade at 181.85 for 4546.25 at 2024-06-27 04:05:00
# Account Balance: 52030.0
# Entered trade at 134.45 for 3361.2499999999995 at 2024-06-27 04:05:00
# Account Balance: 49150.0
# Entered trade at 115.2 for 2880.0 at 2024-06-27 04:05:00
# Account Balance: 45218.75
# Entered trade at 157.25 for 3931.25 at 2024-06-27 04:05:00
# Account Balance: 35477.5
# Entered trade at 389.65 for 9741.25 at 2024-06-27 04:05:00
# Account Balance: 24555.0
# Entered trade at 436.9 for 10922.5 at 2024-06-27 04:05:00
# Account Balance: 12333.75
# Entered trade at 488.85 for 12221.25 at 2024-06-27 04:05:00
# Missed trade at 600.75 due to insufficient balance at 2024-06-27 04:05:00
# Account Balance: 3731.25
# Entered trade at 344.1 for 8602.5 at 2024-06-27 04:05:00
# Exiting trade at 193.246 at 2024-06-27 04:06:00
# Account Balance: 8503.104312759999
# Exiting trade at 167.302 at 2024-06-27 04:06:00
# Account Balance: 12627.982516879998
# Exiting trade at 123.69399999999999 at 2024-06-27 04:06:00
# Account Balance: 15665.390240519997
# Exiting trade at 105.98400000000001 at 2024-06-27 04:06:00
# Account Balance: 18261.156471559996
# Exiting trade at 144.67000000000002 at 2024-06-27 04:06:00
# Account Balance: 21821.651261759995
# Exiting trade at 509.26800000000003 at 2024-06-27 04:30:00
# Account Balance: 34477.49592133999
# Exiting trade at 576.6819999999999 at 2024-06-27 04:31:00
# Account Balance: 48814.89735000999
# Exiting trade at 646.612 at 2024-06-27 04:31:00
# Account Balance: 64896.61397822999
# Exiting trade at 723.498 at 2024-06-27 04:31:00
# Account Balance: 82896.15440785998
# Exiting trade at 983.3860000000001 at 2024-06-27 04:32:00
# Account Balance: 107378.27153676999
# Exiting trade at 1077.44 at 2024-06-27 04:33:00
# Account Balance: 134206.44646317
# Entering 25 trades at 2024-06-28 04:05:00
# Account Balance: 127735.19646317
# Entered trade at 258.85 for 6471.250000000001 at 2024-06-28 04:05:00
# Account Balance: 123360.19646317
# Entered trade at 175.0 for 4375.0 at 2024-06-28 04:05:00
# Account Balance: 118358.94646317
# Entered trade at 200.05 for 5001.25 at 2024-06-28 04:05:00
# Account Balance: 112661.44646317
# Entered trade at 227.9 for 5697.5 at 2024-06-28 04:05:00
# Account Balance: 105336.44646317
# Entered trade at 293.0 for 7325.0 at 2024-06-28 04:05:00
# Account Balance: 96002.69646317
# Entered trade at 373.35 for 9333.75 at 2024-06-28 04:05:00
# Account Balance: 85563.94646317
# Entered trade at 417.55 for 10438.75 at 2024-06-28 04:05:00
# Account Balance: 79816.44646317
# Entered trade at 229.9 for 5747.5 at 2024-06-28 04:05:00
# Account Balance: 75565.19646317
# Entered trade at 170.05 for 4251.25 at 2024-06-28 04:05:00
# Account Balance: 71943.94646317
# Entered trade at 144.85 for 3621.25 at 2024-06-28 04:05:00
# Account Balance: 70931.44646317
# Entered trade at 40.5 for 1012.5 at 2024-06-28 04:05:00
# Account Balance: 69457.69646317
# Entered trade at 58.95 for 1473.75 at 2024-06-28 04:05:00
# Account Balance: 67668.94646317
# Entered trade at 71.55 for 1788.75 at 2024-06-28 04:05:00
# Account Balance: 65517.696463169996
# Entered trade at 86.05 for 2151.25 at 2024-06-28 04:05:00
# Account Balance: 62937.696463169996
# Entered trade at 103.2 for 2580.0 at 2024-06-28 04:05:00
# Account Balance: 54678.946463169996
# Entered trade at 330.35 for 8258.75 at 2024-06-28 04:05:00
# Account Balance: 42982.696463169996
# Entered trade at 467.85 for 11696.25 at 2024-06-28 04:05:00
# Account Balance: 39926.446463169996
# Entered trade at 122.25 for 3056.25 at 2024-06-28 04:05:00
# Account Balance: 37720.196463169996
# Entered trade at 88.25 for 2206.25 at 2024-06-28 04:05:00
# Account Balance: 33782.696463169996
# Entered trade at 157.5 for 3937.5 at 2024-06-28 04:05:00
# Account Balance: 32130.196463169996
# Entered trade at 66.1 for 1652.4999999999998 at 2024-06-28 04:05:00
# Account Balance: 25442.696463169996
# Entered trade at 267.5 for 6687.5 at 2024-06-28 04:05:00
# Account Balance: 20252.696463169996
# Entered trade at 207.6 for 5190.0 at 2024-06-28 04:05:00
# Account Balance: 15727.696463169996
# Entered trade at 181.0 for 4525.0 at 2024-06-28 04:05:00
# Account Balance: 12761.446463169996
# Entered trade at 118.65 for 2966.25 at 2024-06-28 04:05:00
# Exiting trade at 154.0 at 2024-06-28 04:07:00
# Account Balance: 16554.490265669996
# Exiting trade at 37.260000000000005 at 2024-06-28 04:07:00
# Account Balance: 17436.458081269997
# Exiting trade at 54.234 at 2024-06-28 04:07:00
# Account Balance: 18741.713457309997
# Exiting trade at 79.166 at 2024-06-28 04:07:00
# Account Balance: 20668.708285269997
# Exiting trade at 65.826 at 2024-06-28 04:08:00
# Account Balance: 22263.038092829996
# Exiting trade at 94.944 at 2024-06-28 04:08:00
# Account Balance: 24583.495341469996
# Exiting trade at 80.3075 at 2024-06-28 04:09:00
# Account Balance: 26538.941469763748
# Exiting trade at 60.150999999999996 at 2024-06-28 04:09:00
# Account Balance: 27991.740439511246
# Exiting trade at 107.9715 at 2024-06-28 04:09:00
# Account Balance: 30637.049936644995
# Exiting trade at 227.788 at 2024-06-28 04:10:00
# Account Balance: 36270.1191268
# Exiting trade at 176.044 at 2024-06-28 04:10:00
# Account Balance: 40612.866399315
# Exiting trade at 200.552 at 2024-06-28 04:10:00
# Account Balance: 45566.76104268499
# Exiting trade at 257.84 at 2024-06-28 04:10:00
# Account Balance: 51949.226380584994
# Exiting trade at 328.548 at 2024-06-28 04:10:00
# Account Balance: 60094.91223008999
# Exiting trade at 367.444 at 2024-06-28 04:10:00
# Account Balance: 69210.53394285499
# Exiting trade at 211.508 at 2024-06-28 04:10:00
# Account Balance: 74437.795197335
# Exiting trade at 156.44600000000003 at 2024-06-28 04:10:00
# Account Balance: 78291.952902095
# Exiting trade at 133.262 at 2024-06-28 04:10:00
# Account Balance: 81567.961743815
# Exiting trade at 290.708 at 2024-06-28 04:10:00
# Account Balance: 88770.04483042
# Exiting trade at 112.47 at 2024-06-28 04:10:00
# Account Balance: 91527.55508861999
# Exiting trade at 143.32500000000002 at 2024-06-28 04:10:00
# Account Balance: 95054.4827396825
# Exiting trade at 243.425 at 2024-06-28 04:10:00
# Account Balance: 101077.626527995
# Exiting trade at 188.916 at 2024-06-28 04:10:00
# Account Balance: 105741.467165205
# Exiting trade at 164.71 at 2024-06-28 04:10:00
# Account Balance: 109801.67735468
# Exiting trade at 411.708 at 2024-06-28 04:11:00
# Account Balance: 120021.09485753499
# Entering 7 trades at 2024-07-01 04:05:00
# Account Balance: 114389.84485753499
# Entered trade at 225.25 for 5631.25 at 2024-07-01 04:05:00
# Account Balance: 112804.84485753499
# Entered trade at 63.4 for 1585.0 at 2024-07-01 04:05:00
# Account Balance: 108819.84485753499
# Entered trade at 159.4 for 3985.0 at 2024-07-01 04:05:00
# Account Balance: 106293.59485753499
# Entered trade at 101.05 for 2526.25 at 2024-07-01 04:05:00
# Account Balance: 103129.84485753499
# Entered trade at 126.55 for 3163.75 at 2024-07-01 04:05:00
# Account Balance: 98406.09485753499
# Entered trade at 188.95 for 4723.75 at 2024-07-01 04:05:00
# Account Balance: 94521.09485753499
# Entered trade at 155.4 for 3885.0 at 2024-07-01 04:05:00
# Exiting trade at 207.23000000000002 at 2024-07-01 04:06:00
# Account Balance: 99641.673881335
# Exiting trade at 58.328 at 2024-07-01 04:06:00
# Account Balance: 101049.023005015
# Exiting trade at 92.96600000000001 at 2024-07-01 04:06:00
# Account Balance: 103320.154060975
# Exiting trade at 116.426 at 2024-07-01 04:06:00
# Account Balance: 106176.316704535
# Exiting trade at 173.834 at 2024-07-01 04:06:00
# Account Balance: 110464.086056575
# Exiting trade at 142.96800000000002 at 2024-07-01 04:06:00
# Account Balance: 113982.13737865501
# Exiting trade at 224.754 at 2024-07-01 06:00:00
# Account Balance: 119541.02505352002
# Entering 13 trades at 2024-07-02 04:05:00
# Account Balance: 112001.02505352002
# Entered trade at 301.6 for 7540.000000000001 at 2024-07-02 04:05:00
# Account Balance: 106703.52505352002
# Entered trade at 211.9 for 5297.5 at 2024-07-02 04:05:00
# Account Balance: 103682.27505352002
# Entered trade at 120.85 for 3021.25 at 2024-07-02 04:05:00
# Account Balance: 99323.52505352002
# Entered trade at 174.35 for 4358.75 at 2024-07-02 04:05:00
# Account Balance: 95734.77505352002
# Entered trade at 143.55 for 3588.7500000000005 at 2024-07-02 04:05:00
# Account Balance: 91356.02505352002
# Entered trade at 175.15 for 4378.75 at 2024-07-02 04:05:00
# Account Balance: 89349.77505352002
# Entered trade at 80.25 for 2006.25 at 2024-07-02 04:05:00
# Account Balance: 86884.77505352002
# Entered trade at 98.6 for 2465.0 at 2024-07-02 04:05:00
# Account Balance: 80547.27505352002
# Entered trade at 253.5 for 6337.5 at 2024-07-02 04:05:00
# Account Balance: 79249.77505352002
# Entered trade at 51.9 for 1297.5 at 2024-07-02 04:05:00
# Account Balance: 77942.27505352002
# Entered trade at 52.3 for 1307.5 at 2024-07-02 04:05:00
# Account Balance: 75731.02505352002
# Entered trade at 88.45 for 2211.25 at 2024-07-02 04:05:00
# Account Balance: 75019.77505352002
# Entered trade at 28.45 for 711.25 at 2024-07-02 04:05:00
# Exiting trade at 71.651 at 2024-07-02 04:06:00
# Account Balance: 76759.75864151752
# Exiting trade at 121.17650000000002 at 2024-07-02 04:06:00
# Account Balance: 79735.05172676376
# Exiting trade at 38.9765 at 2024-07-02 04:06:00
# Account Balance: 80660.03859251001
# Exiting trade at 113.15249999999999 at 2024-07-02 04:09:00
# Account Balance: 83435.22589431626
# Exiting trade at 73.17899999999999 at 2024-07-02 04:09:00
# Account Balance: 85213.34553249375
# Exiting trade at 258.038 at 2024-07-02 04:12:00
# Account Balance: 91602.57632702375
# Exiting trade at 212.454 at 2024-07-02 04:12:00
# Account Balance: 96854.77202851375
# Exiting trade at 446.36800000000005 at 2024-07-02 04:13:00
# Account Balance: 107941.65592659375
# Exiting trade at 313.612 at 2024-07-02 04:13:00
# Account Balance: 115717.10969981375
# Exiting trade at 375.18 at 2024-07-02 04:13:00
# Account Balance: 125028.29918311375
# Exiting trade at 170.39849999999998 at 2024-07-02 04:14:00
# Account Balance: 129231.38585505499
# Exiting trade at 139.02599999999998 at 2024-07-02 04:14:00
# Account Balance: 132651.94146824
# Exiting trade at 246.9615 at 2024-07-02 04:15:00
# Account Balance: 138764.75562289875
# Entering 17 trades at 2024-07-03 04:05:00
# Account Balance: 129839.75562289875
# Entered trade at 357.0 for 8925.0 at 2024-07-03 04:05:00
# Account Balance: 126939.75562289875
# Entered trade at 116.0 for 2900.0 at 2024-07-03 04:05:00
# Account Balance: 123028.50562289875
# Entered trade at 156.45 for 3911.2499999999995 at 2024-07-03 04:05:00
# Account Balance: 117898.50562289875
# Entered trade at 205.2 for 5130.0 at 2024-07-03 04:05:00
# Account Balance: 111283.50562289875
# Entered trade at 264.6 for 6615.000000000001 at 2024-07-03 04:05:00
# Account Balance: 102991.00562289875
# Entered trade at 331.7 for 8292.5 at 2024-07-03 04:05:00
# Account Balance: 92742.25562289875
# Entered trade at 409.95 for 10248.75 at 2024-07-03 04:05:00
# Account Balance: 80447.25562289875
# Entered trade at 491.8 for 12295.0 at 2024-07-03 04:05:00
# Account Balance: 73982.25562289875
# Entered trade at 258.6 for 6465.000000000001 at 2024-07-03 04:05:00
# Account Balance: 69573.50562289875
# Entered trade at 176.35 for 4408.75 at 2024-07-03 04:05:00
# Account Balance: 66047.25562289875
# Entered trade at 141.05 for 3526.2500000000005 at 2024-07-03 04:05:00
# Account Balance: 63319.75562289875
# Entered trade at 109.1 for 2727.5 at 2024-07-03 04:05:00
# Account Balance: 61278.50562289875
# Entered trade at 81.65 for 2041.2500000000002 at 2024-07-03 04:05:00
# Account Balance: 59802.25562289875
# Entered trade at 59.05 for 1476.25 at 2024-07-03 04:05:00
# Account Balance: 44867.25562289875
# Entered trade at 597.4 for 14935.0 at 2024-07-03 04:05:00
# Account Balance: 32082.255622898752
# Entered trade at 511.4 for 12785.0 at 2024-07-03 04:05:00
# Account Balance: 21252.255622898752
# Entered trade at 433.2 for 10830.0 at 2024-07-03 04:05:00
# Exiting trade at 528.36 at 2024-07-03 04:06:00
# Account Balance: 34384.32601949875
# Exiting trade at 158.92000000000002 at 2024-07-03 04:06:00
# Account Balance: 38301.05137719875
# Exiting trade at 756.872 at 2024-07-03 04:06:00
# Account Balance: 57133.06392851875
# Exiting trade at 641.136 at 2024-07-03 04:06:00
# Account Balance: 73078.18867867875
# Exiting trade at 884.1519999999999 at 2024-07-03 04:07:00
# Account Balance: 95085.03947679875
# Exiting trade at 214.3365 at 2024-07-03 04:13:00
# Account Balance: 100384.012944145
# Exiting trade at 83.2605 at 2024-07-03 04:14:00
# Account Balance: 102413.59761918125
# Exiting trade at 281.124 at 2024-07-03 04:15:00
# Account Balance: 109378.44488987126
# Exiting trade at 115.12650000000001 at 2024-07-03 04:15:00
# Account Balance: 112202.87010099251
# Exiting trade at 153.831 at 2024-07-03 04:16:00
# Account Balance: 115992.71003404
# Exiting trade at 362.50200000000007 at 2024-07-03 04:19:00
# Account Balance: 124987.36046203501
# Exiting trade at 198.8805 at 2024-07-03 04:19:00
# Account Balance: 129900.87982552126
# Exiting trade at 248.65349999999998 at 2024-07-03 04:23:00
# Account Balance: 136055.89790245
# Exiting trade at 454.42900000000003 at 2024-07-03 04:24:00
# Account Balance: 147343.4741192525
# Exiting trade at 463.05 at 2024-07-03 09:59:00
# Account Balance: 158844.97653675248
# Exiting trade at 547.8 at 2024-07-03 09:59:00
# Account Balance: 172460.08218775247
# Exiting trade at 303.0 at 2024-07-03 09:59:00
# Account Balance: 179970.0046837525
# Entering 18 trades at 2024-07-04 04:05:00
# Account Balance: 177117.5046837525
# Entered trade at 114.1 for 2852.5 at 2024-07-04 04:05:00
# Account Balance: 175132.5046837525
# Entered trade at 79.4 for 1985.0000000000002 at 2024-07-04 04:05:00
# Account Balance: 167793.7546837525
# Entered trade at 293.55 for 7338.75 at 2024-07-04 04:05:00
# Account Balance: 162123.7546837525
# Entered trade at 226.8 for 5670.0 at 2024-07-04 04:05:00
# Account Balance: 157895.0046837525
# Entered trade at 169.15 for 4228.75 at 2024-07-04 04:05:00
# Account Balance: 154840.0046837525
# Entered trade at 122.2 for 3055.0 at 2024-07-04 04:05:00
# Account Balance: 148765.0046837525
# Entered trade at 243.0 for 6075.0 at 2024-07-04 04:05:00
# Account Balance: 142267.5046837525
# Entered trade at 259.9 for 6497.499999999999 at 2024-07-04 04:05:00
# Account Balance: 132710.0046837525
# Entered trade at 382.3 for 9557.5 at 2024-07-04 04:05:00
# Account Balance: 121982.50468375249
# Entered trade at 429.1 for 10727.5 at 2024-07-04 04:05:00
# Account Balance: 98503.75468375249
# Entered trade at 939.15 for 23478.75 at 2024-07-04 04:05:00
# Account Balance: 78763.75468375249
# Entered trade at 789.6 for 19740.0 at 2024-07-04 04:05:00
# Account Balance: 60763.754683752486
# Entered trade at 720.0 for 18000.0 at 2024-07-04 04:05:00
# Account Balance: 44351.254683752486
# Entered trade at 656.5 for 16412.5 at 2024-07-04 04:05:00
# Account Balance: 29476.254683752486
# Entered trade at 595.0 for 14875.0 at 2024-07-04 04:05:00
# Account Balance: 16087.504683752488
# Entered trade at 535.55 for 13388.749999999998 at 2024-07-04 04:05:00
# Account Balance: 4058.754683752488
# Entered trade at 481.15 for 12028.75 at 2024-07-04 04:05:00
# Missed trade at 863.45 due to insufficient balance at 2024-07-04 04:05:00
# Exiting trade at 112.424 at 2024-07-04 04:09:00
# Account Balance: 6815.117821192488
# Exiting trade at 160.88099999999997 at 2024-07-04 04:14:00
# Account Balance: 10780.807430364988
# Exiting trade at 111.95400000000001 at 2024-07-04 04:14:00
# Account Balance: 13526.100287229989
# Exiting trade at 208.656 at 2024-07-04 04:54:00
# Account Balance: 18682.240054589987
# Exiting trade at 155.61800000000002 at 2024-07-04 04:54:00
# Account Balance: 22515.74958566999
# Exiting trade at 228.712 at 2024-07-04 04:54:00
# Account Balance: 28171.860238639987
# Exiting trade at 336.42400000000004 at 2024-07-04 04:54:00
# Account Balance: 36513.947128329986
# Exiting trade at 270.06600000000003 at 2024-07-04 04:57:00
# Account Balance: 43201.493110289986
# Exiting trade at 377.608 at 2024-07-04 04:57:00
# Account Balance: 52570.57091401999
# Exiting trade at 423.412 at 2024-07-04 04:57:00
# Account Balance: 63081.84694586499
# Exiting trade at 633.6 at 2024-07-04 05:03:00
# Account Balance: 78834.507161865
# Exiting trade at 577.72 at 2024-07-04 05:03:00
# Account Balance: 93193.707483815
# Exiting trade at 523.6 at 2024-07-04 05:03:00
# Account Balance: 106203.336412315
# Exiting trade at 471.28399999999993 at 2024-07-04 05:03:00
# Account Balance: 117908.37966047999
# Exiting trade at 221.13 at 2024-07-04 05:04:00
# Account Balance: 123375.54803640499
# Exiting trade at 826.452 at 2024-07-04 05:04:00
# Account Balance: 143937.29070565
# Exiting trade at 694.8480000000001 at 2024-07-04 05:04:00
# Account Balance: 161217.27074253
# Entering 18 trades at 2024-07-05 04:05:00
# Account Balance: 153044.77074253
# Entered trade at 326.9 for 8172.499999999999 at 2024-07-05 04:05:00
# Account Balance: 149728.52074253
# Entered trade at 132.65 for 3316.25 at 2024-07-05 04:05:00
# Account Balance: 145062.27074253
# Entered trade at 186.65 for 4666.25 at 2024-07-05 04:05:00
# Account Balance: 137512.27074253
# Entered trade at 302.0 for 7550.0 at 2024-07-05 04:05:00
# Account Balance: 134713.52074253
# Entered trade at 111.95 for 2798.75 at 2024-07-05 04:05:00
# Account Balance: 127034.77074253
# Entered trade at 307.15 for 7678.749999999999 at 2024-07-05 04:05:00
# Account Balance: 122954.77074253
# Entered trade at 163.2 for 4079.9999999999995 at 2024-07-05 04:05:00
# Account Balance: 112866.02074253
# Entered trade at 403.55 for 10088.75 at 2024-07-05 04:05:00
# Account Balance: 107184.77074253
# Entered trade at 227.25 for 5681.25 at 2024-07-05 04:05:00
# Account Balance: 105324.77074253
# Entered trade at 74.4 for 1860.0000000000002 at 2024-07-05 04:05:00
# Account Balance: 87251.02074253
# Entered trade at 722.95 for 18073.75 at 2024-07-05 04:05:00
# Account Balance: 70971.02074253
# Entered trade at 651.2 for 16280.000000000002 at 2024-07-05 04:05:00
# Account Balance: 56449.77074253
# Entered trade at 580.85 for 14521.25 at 2024-07-05 04:05:00
# Account Balance: 43533.52074253
# Entered trade at 516.65 for 12916.25 at 2024-07-05 04:05:00
# Account Balance: 32079.770742530003
# Entered trade at 458.15 for 11453.75 at 2024-07-05 04:05:00
# Account Balance: 25838.520742530003
# Entered trade at 249.65 for 6241.25 at 2024-07-05 04:05:00
# Account Balance: 16991.020742530003
# Entered trade at 353.9 for 8847.5 at 2024-07-05 04:05:00
# Account Balance: 10299.770742530003
# Entered trade at 267.65 for 6691.249999999999 at 2024-07-05 04:05:00
# Exiting trade at 153.37150000000003 at 2024-07-05 04:06:00
# Account Balance: 14078.100430413753
# Exiting trade at 454.58199999999994 at 2024-07-05 04:06:00
# Account Balance: 25369.87214558375
# Exiting trade at 223.584 at 2024-07-05 04:06:00
# Account Balance: 30899.50506262375
# Exiting trade at 597.254 at 2024-07-05 04:06:00
# Account Balance: 45750.04895211375
# Exiting trade at 101.92800000000001 at 2024-07-05 04:06:00
# Account Balance: 48245.22866429375
# Exiting trade at 764.6419999999999 at 2024-07-05 04:06:00
# Account Balance: 67271.05401556374
# Exiting trade at 678.062 at 2024-07-05 04:06:00
# Account Balance: 84137.25102453375
# Exiting trade at 523.7719999999999 at 2024-07-05 04:06:00
# Account Balance: 97154.87957735374
# Exiting trade at 396.12199999999996 at 2024-07-05 04:06:00
# Account Balance: 106988.44070242374
# Exiting trade at 120.71150000000002 at 2024-07-05 04:11:00
# Account Balance: 109951.45043520749
# Exiting trade at 169.85150000000002 at 2024-07-05 04:11:00
# Account Balance: 114139.87536264124
# Exiting trade at 297.479 at 2024-07-05 04:12:00
# Account Balance: 121510.97586506873
# Exiting trade at 227.1815 at 2024-07-05 04:12:00
# Account Balance: 127129.05185292749
# Exiting trade at 413.74 at 2024-07-05 04:22:00
# Account Balance: 137401.72649107748
# Exiting trade at 311.33250000000004 at 2024-07-05 04:22:00
# Account Balance: 145120.06129743374
# Exiting trade at 1069.9660000000001 at 2024-07-05 04:22:00
# Account Balance: 171761.80676864373
# Exiting trade at 963.7760000000001 at 2024-07-05 04:22:00
# Account Balance: 195754.77730720374
# Exiting trade at 859.658 at 2024-07-05 04:22:00
# Account Balance: 217150.65632643373
# Entering 12 trades at 2024-07-08 04:05:00
# Account Balance: 214661.90632643373
# Entered trade at 99.55 for 2488.75 at 2024-07-08 04:05:00
# Account Balance: 211549.40632643373
# Entered trade at 124.5 for 3112.5 at 2024-07-08 04:05:00
# Account Balance: 207695.65632643373
# Entered trade at 154.15 for 3853.75 at 2024-07-08 04:05:00
# Account Balance: 197281.90632643373
# Entered trade at 416.55 for 10413.75 at 2024-07-08 04:05:00
# Account Balance: 193541.90632643373
# Entered trade at 149.6 for 3740.0 at 2024-07-08 04:05:00
# Account Balance: 191189.40632643373
# Entered trade at 94.1 for 2352.5 at 2024-07-08 04:05:00
# Account Balance: 182226.90632643373
# Entered trade at 358.5 for 8962.5 at 2024-07-08 04:05:00
# Account Balance: 181119.40632643373
# Entered trade at 44.3 for 1107.5 at 2024-07-08 04:05:00
# Account Balance: 176358.15632643373
# Entered trade at 190.45 for 4761.25 at 2024-07-08 04:05:00
# Account Balance: 176111.90632643373
# Entered trade at 9.85 for 246.25 at 2024-07-08 04:05:00
# Account Balance: 171428.15632643373
# Entered trade at 187.35 for 4683.75 at 2024-07-08 04:05:00
# Account Balance: 169490.65632643373
# Entered trade at 77.5 for 1937.5 at 2024-07-08 04:05:00
# Exiting trade at 128.917 at 2024-07-08 04:06:00
# Account Balance: 172659.01991401624
# Exiting trade at 13.4945 at 2024-07-08 04:06:00
# Account Balance: 172948.4118517175
# Exiting trade at 40.312999999999995 at 2024-07-08 04:09:00
# Account Balance: 173906.50616881
# Exiting trade at 90.5905 at 2024-07-08 04:10:00
# Account Balance: 176118.38177302125
# Exiting trade at 113.295 at 2024-07-08 04:10:00
# Account Balance: 178896.44458290873
# Exiting trade at 140.2765 at 2024-07-08 04:10:00
# Account Balance: 182347.351106155
# Exiting trade at 70.525 at 2024-07-08 04:10:00
# Account Balance: 184058.8488392175
# Exiting trade at 137.632 at 2024-07-08 04:11:00
# Account Balance: 187443.83415313752
# Exiting trade at 167.596 at 2024-07-08 04:11:00
# Account Balance: 191575.91662277252
# Exiting trade at 170.4885 at 2024-07-08 04:11:00
# Account Balance: 195780.22656198876
# Exiting trade at 315.48 at 2024-07-08 04:13:00
# Account Balance: 203600.04029453878
# Exiting trade at 366.564 at 2024-07-08 04:14:00
# Account Balance: 212693.7177570038
# Entering 9 trades at 2024-07-09 04:05:00
# Account Balance: 209848.7177570038
# Entered trade at 113.8 for 2845.0 at 2024-07-09 04:05:00
# Account Balance: 208849.9677570038
# Entered trade at 39.95 for 998.7500000000001 at 2024-07-09 04:05:00
# Account Balance: 207111.2177570038
# Entered trade at 69.55 for 1738.75 at 2024-07-09 04:05:00
# Account Balance: 198124.9677570038
# Entered trade at 359.45 for 8986.25 at 2024-07-09 04:05:00
# Account Balance: 192983.7177570038
# Entered trade at 205.65 for 5141.25 at 2024-07-09 04:05:00
# Account Balance: 189953.7177570038
# Entered trade at 121.2 for 3030.0 at 2024-07-09 04:05:00
# Account Balance: 184913.7177570038
# Entered trade at 201.6 for 5040.0 at 2024-07-09 04:05:00
# Account Balance: 184222.4677570038
# Entered trade at 27.65 for 691.25 at 2024-07-09 04:05:00
# Account Balance: 179829.9677570038
# Entered trade at 175.7 for 4392.5 at 2024-07-09 04:05:00
# Exiting trade at 189.198 at 2024-07-09 04:06:00
# Account Balance: 184500.8754428838
# Exiting trade at 111.504 at 2024-07-09 04:06:00
# Account Balance: 187234.2961651238
# Exiting trade at 25.438 at 2024-07-09 04:06:00
# Account Balance: 187821.45394540377
# Exiting trade at 177.408 at 2024-07-09 04:07:00
# Account Balance: 192198.21480588376
# Exiting trade at 36.3545 at 2024-07-09 04:08:00
# Account Balance: 193057.595121185
# Exiting trade at 103.558 at 2024-07-09 04:09:00
# Account Balance: 195592.84417954
# Exiting trade at 63.2905 at 2024-07-09 04:09:00
# Account Balance: 197123.93356450126
# Exiting trade at 316.316 at 2024-07-09 04:09:00
# Account Balance: 204964.59433483626
# Exiting trade at 159.887 at 2024-07-09 04:12:00
# Account Balance: 208904.53229224376
# Entering 19 trades at 2024-07-10 04:05:00
# Account Balance: 205340.78229224376
# Entered trade at 142.55 for 3563.7500000000005 at 2024-07-10 04:05:00
# Account Balance: 201204.53229224376
# Entered trade at 165.45 for 4136.25 at 2024-07-10 04:05:00
# Account Balance: 196482.03229224376
# Entered trade at 188.9 for 4722.5 at 2024-07-10 04:05:00
# Account Balance: 193947.03229224376
# Entered trade at 101.4 for 2535.0 at 2024-07-10 04:05:00
# Account Balance: 183969.53229224376
# Entered trade at 399.1 for 9977.5 at 2024-07-10 04:05:00
# Account Balance: 171027.03229224376
# Entered trade at 517.7 for 12942.500000000002 at 2024-07-10 04:05:00
# Account Balance: 166264.53229224376
# Entered trade at 190.5 for 4762.5 at 2024-07-10 04:05:00
# Account Balance: 162435.78229224376
# Entered trade at 153.15 for 3828.75 at 2024-07-10 04:05:00
# Account Balance: 159469.53229224376
# Entered trade at 118.65 for 2966.25 at 2024-07-10 04:05:00
# Account Balance: 157269.53229224376
# Entered trade at 88.0 for 2200.0 at 2024-07-10 04:05:00
# Account Balance: 156202.03229224376
# Entered trade at 42.7 for 1067.5 at 2024-07-10 04:05:00
# Account Balance: 144194.53229224376
# Entered trade at 480.3 for 12007.5 at 2024-07-10 04:05:00
# Account Balance: 130244.53229224376
# Entered trade at 558.0 for 13950.0 at 2024-07-10 04:05:00
# Account Balance: 123137.03229224376
# Entered trade at 284.3 for 7107.5 at 2024-07-10 04:05:00
# Account Balance: 114798.28229224376
# Entered trade at 333.55 for 8338.75 at 2024-07-10 04:05:00
# Account Balance: 104487.03229224376
# Entered trade at 412.45 for 10311.25 at 2024-07-10 04:05:00
# Account Balance: 92919.53229224376
# Entered trade at 462.7 for 11567.5 at 2024-07-10 04:05:00
# Account Balance: 86619.53229224376
# Entered trade at 252.0 for 6300.0 at 2024-07-10 04:05:00
# Account Balance: 77440.78229224376
# Entered trade at 367.15 for 9178.75 at 2024-07-10 04:05:00
# Exiting trade at 131.14600000000002 at 2024-07-10 04:06:00
# Account Balance: 80664.02357900377
# Exiting trade at 152.214 at 2024-07-10 04:06:00
# Account Balance: 84412.64617384376
# Exiting trade at 173.788 at 2024-07-10 04:06:00
# Account Balance: 88699.26840512376
# Exiting trade at 93.28800000000001 at 2024-07-10 04:06:00
# Account Balance: 90978.42930640376
# Exiting trade at 351.208 at 2024-07-10 04:06:00
# Account Balance: 99689.17960113376
# Exiting trade at 38.857000000000006 at 2024-07-10 04:06:00
# Account Balance: 100610.96531986626
# Exiting trade at 422.664 at 2024-07-10 04:06:00
# Account Balance: 111103.58873895626
# Exiting trade at 491.04 at 2024-07-10 04:06:00
# Account Balance: 123301.28040635625
# Exiting trade at 250.184 at 2024-07-10 04:06:00
# Account Balance: 129492.83076664625
# Exiting trade at 293.524 at 2024-07-10 04:06:00
# Account Balance: 136765.13545421124
# Exiting trade at 231.84 at 2024-07-10 04:06:00
# Account Balance: 142499.42408461124
# Exiting trade at 323.092 at 2024-07-10 04:06:00
# Account Balance: 150509.05558225623
# Exiting trade at 362.956 at 2024-07-10 04:09:00
# Account Balance: 159512.76161849123
# Exiting trade at 407.176 at 2024-07-10 04:09:00
# Account Balance: 169619.16623230124
# Exiting trade at 455.576 at 2024-07-10 04:10:00
# Account Balance: 180932.50461261126
# Exiting trade at 173.35500000000002 at 2024-07-10 04:15:00
# Account Balance: 185208.29710484875
# Exiting trade at 139.3665 at 2024-07-10 04:15:00
# Account Balance: 188636.51075412
# Exiting trade at 107.9715 at 2024-07-10 04:15:00
# Account Balance: 191281.82025125375
# Exiting trade at 80.08 at 2024-07-10 04:15:00
# Account Balance: 193231.59316105375
# Entering 7 trades at 2024-07-11 04:05:00
# Account Balance: 186917.84316105375
# Entered trade at 252.55 for 6313.75 at 2024-07-11 04:05:00
# Account Balance: 183526.59316105375
# Entered trade at 135.65 for 3391.25 at 2024-07-11 04:05:00
# Account Balance: 172489.09316105375
# Entered trade at 441.5 for 11037.5 at 2024-07-11 04:05:00
# Account Balance: 164020.34316105375
# Entered trade at 338.75 for 8468.75 at 2024-07-11 04:05:00
# Account Balance: 151545.34316105375
# Entered trade at 499.0 for 12475.0 at 2024-07-11 04:05:00
# Account Balance: 149894.09316105375
# Entered trade at 66.05 for 1651.25 at 2024-07-11 04:05:00
# Account Balance: 140210.34316105375
# Entered trade at 387.35 for 9683.75 at 2024-07-11 04:05:00
# Exiting trade at 60.766 at 2024-07-11 04:18:00
# Account Balance: 141678.48968501374
# Exiting trade at 124.79800000000002 at 2024-07-11 04:21:00
# Account Balance: 144743.42830689374
# Exiting trade at 222.244 at 2024-07-11 04:22:00
# Account Balance: 150238.24872015874
# Exiting trade at 298.1 at 2024-07-11 04:22:00
# Account Balance: 157624.66350928374
# Exiting trade at 388.52 at 2024-07-11 04:31:00
# Account Balance: 167265.85001673375
# Exiting trade at 340.868 at 2024-07-11 04:31:00
# Account Balance: 175718.75537043874
# Exiting trade at 439.12 at 2024-07-11 04:33:00
# Account Balance: 186621.73627013873
# Entering 20 trades at 2024-07-12 04:05:00
# Account Balance: 184167.98627013873
# Entered trade at 98.15 for 2453.75 at 2024-07-12 04:05:00
# Account Balance: 182199.23627013873
# Entered trade at 78.75 for 1968.75 at 2024-07-12 04:05:00
# Account Balance: 174101.73627013873
# Entered trade at 323.9 for 8097.499999999999 at 2024-07-12 04:05:00
# Account Balance: 172841.73627013873
# Entered trade at 50.4 for 1260.0 at 2024-07-12 04:05:00
# Account Balance: 172435.48627013873
# Entered trade at 16.25 for 406.25 at 2024-07-12 04:05:00
# Account Balance: 169365.48627013873
# Entered trade at 122.8 for 3070.0 at 2024-07-12 04:05:00
# Account Balance: 162102.98627013873
# Entered trade at 290.5 for 7262.5 at 2024-07-12 04:05:00
# Account Balance: 157049.23627013873
# Entered trade at 202.15 for 5053.75 at 2024-07-12 04:05:00
# Account Balance: 152156.73627013873
# Entered trade at 195.7 for 4892.5 at 2024-07-12 04:05:00
# Account Balance: 146131.73627013873
# Entered trade at 241.0 for 6025.0 at 2024-07-12 04:05:00
# Account Balance: 141852.98627013873
# Entered trade at 171.15 for 4278.75 at 2024-07-12 04:05:00
# Account Balance: 139006.73627013873
# Entered trade at 113.85 for 2846.25 at 2024-07-12 04:05:00
# Account Balance: 137257.98627013873
# Entered trade at 69.95 for 1748.75 at 2024-07-12 04:05:00
# Account Balance: 134247.98627013873
# Entered trade at 120.4 for 3010.0 at 2024-07-12 04:05:00
# Account Balance: 127346.73627013873
# Entered trade at 276.05 for 6901.25 at 2024-07-12 04:05:00
# Account Balance: 114016.73627013873
# Entered trade at 533.2 for 13330.000000000002 at 2024-07-12 04:05:00
# Account Balance: 102419.23627013873
# Entered trade at 463.9 for 11597.5 at 2024-07-12 04:05:00
# Account Balance: 93832.98627013873
# Entered trade at 343.45 for 8586.25 at 2024-07-12 04:05:00
# Account Balance: 89279.23627013873
# Entered trade at 182.15 for 4553.75 at 2024-07-12 04:05:00
# Account Balance: 82960.48627013873
# Entered trade at 252.75 for 6318.75 at 2024-07-12 04:05:00
# Exiting trade at 90.29800000000002 at 2024-07-12 04:06:00
# Account Balance: 85165.08432201874
# Exiting trade at 72.45 at 2024-07-12 04:06:00
# Account Balance: 86924.59951901874
# Exiting trade at 285.032 at 2024-07-12 04:06:00
# Account Balance: 93985.14219118874
# Exiting trade at 46.368 at 2024-07-12 04:06:00
# Account Balance: 95094.23991726874
# Exiting trade at 22.262500000000003 at 2024-07-12 04:06:00
# Account Balance: 95602.33118504999
# Exiting trade at 168.23600000000002 at 2024-07-12 04:06:00
# Account Balance: 99751.42458095998
# Exiting trade at 299.182 at 2024-07-12 04:06:00
# Account Balance: 107166.94029712999
# Exiting trade at 172.21599999999998 at 2024-07-12 04:06:00
# Account Balance: 111414.23008083999
# Exiting trade at 98.6295 at 2024-07-12 04:06:00
# Account Balance: 113827.16704982874
# Exiting trade at 110.76800000000001 at 2024-07-12 04:06:00
# Account Balance: 116542.23383990875
# Exiting trade at 242.924 at 2024-07-12 04:06:00
# Account Balance: 122552.74413522375
# Exiting trade at 249.54550000000003 at 2024-07-12 04:06:00
# Account Balance: 128729.9320999225
# Exiting trade at 429.94 at 2024-07-12 04:13:00
# Account Balance: 139407.0403638225
# Exiting trade at 508.306 at 2024-07-12 04:13:00
# Account Balance: 152038.8891529325
# Exiting trade at 346.26750000000004 at 2024-07-12 04:13:00
# Account Balance: 160628.60410257627
# Exiting trade at 160.52849999999998 at 2024-07-12 05:23:00
# Account Balance: 164585.50122794253
# Exiting trade at 241.3215 at 2024-07-12 05:24:00
# Account Balance: 170557.6356417013
# Exiting trade at 339.81 at 2024-07-12 05:25:00
# Account Balance: 178986.3900309263
# Exiting trade at 686.572 at 2024-07-12 05:29:00
# Account Balance: 196064.8582017463
# Exiting trade at 789.1360000000001 at 2024-07-12 05:30:00
# Account Balance: 215701.6553319063
# Total trades executed: 175
# Total missed trades: 2
# Live trading simulation complete.
# Final summary statistics:
#    Total Trades  Total Missed Trades   Total Profit  Max Drawdown  \
# 0           175                    2  115701.655332  30528.920056
#
#     Best Trade  Worst Trade
# 0  8628.174926 -2917.007331
# Final Balance: 215701.6553319063
# Max Drawdown: 30528.920056295
# Best Trade: 8628.174926400001
# Worst Trade: -2917.007330754999
# Total Trades: 175
# Total Missed Trades: 2
# Total Profit: 115701.65533190628
# Total Profitable Trades: 68
# Analysis and visualization complete.
